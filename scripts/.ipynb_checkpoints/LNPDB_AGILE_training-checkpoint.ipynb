# %% [markdown]
# # 1. Installation of requirements

# %%
# required packages and basic function(s)
from rdkit import Chem
from mordred import Calculator, descriptors
import pandas as pd
import numpy as np
import math
import random
import tqdm
import os
import shutil
from pathlib import Path
import subprocess
import logging
from multiprocessing import freeze_support

logging.basicConfig(level=logging.INFO)
freeze_support()

def safe_div(value, factor, feature_name, printed_flag):
    try:
        return value / np.float64(factor)
    except Exception:
        # only print the first time this feature fails
        if not printed_flag[0]:
            print(f"{feature_name} unable to be calculated, setting invalid values to 0")
            printed_flag[0] = True
        return 0

# %% [markdown]
# # 2. Splitting data into test/train splits

# %% [markdown]
# The pre-trained AGILE deep learning model is provided in `AGILE/ckpt/pretrained_agile_60k` and will be fine-tuned on five cross-validation splits.
#
# The data provided in [repo](https://github.com/bowang-lab/AGILE) was split (80% train/20% validation) randomly to create these splits.
#
# In this section we will split the data.

# %%
# split AGILE data (Morgan fingerprints included)
random.seed(0)
no_splits = 5

# read from ../LNPDB/data/LNPDB_for_AGILE/data
df = pd.read_csv("../data/LNPDB_for_AGILE/AGILE/data/data/finetuning_set_smiles_plus_features.csv")

def create_df(name):
    name = pd.DataFrame()
    return name

output_dataframes=[]
for i in range(no_splits):
    output_dataframes.append(create_df(f"df{i}"))

complement_dataframes=[]
for k in range(no_splits):
    complement_dataframes.append(create_df(f"df{k}c"))

for index in range(len(df)):
    row = df.iloc[[index]]
    assignment = random.randint(0,no_splits-1)
    while len(output_dataframes[assignment])>=len(df)/no_splits:
        assignment = random.randint(0,no_splits-1)
    output_dataframes[assignment] = pd.concat([output_dataframes[assignment], row], ignore_index=True)
    for complement_assignment in range(no_splits):
        if complement_assignment != assignment:
            complement_dataframes[complement_assignment] = pd.concat([complement_dataframes[complement_assignment], row], ignore_index=True)

# save to ../LNPDB/data/LNPDB_for_AGILE/cv_splits
cv_dir = Path("../data/LNPDB_for_AGILE/cv_splits")
cv_dir.mkdir(parents=True, exist_ok=True)

for j, dataframe in enumerate(output_dataframes):
    dataframe.to_csv(cv_dir / f"df{j}_test.csv", index=False)

for k, dataframe in enumerate(complement_dataframes):
    dataframe.to_csv(cv_dir / f"df{k}_train.csv", index=False)

logging.info("Cross-validation splits saved to cv_splits/")
# Out:
# INFO:root:Cross-validation splits saved to cv_splits/

# %% [markdown]
# # 3. Finetuning models on cross-validation splits

# %% [markdown]
# The following section involves preparing files according to [AGILE](https://github.com/bowang-lab/AGILE).
#
# Note that the trained model checkpoints are already provided at `LNPDB/data/LNPDB_for_AGILE/cv_splits`, so it is not necessary to run the commands.
#
# The models and their results are now placed in `LNPDB/data/LNPDB_for_AGILE/cv_splits`.

# %% [markdown]
# ## 3.1 Preparing finetune_LNPDB.py and YAML/split

# %%
lnpdb_agile_base = Path("../data/LNPDB_for_AGILE")
scripts_dir = lnpdb_agile_base / "scripts"
agile_dir = lnpdb_base / "data/LNPDB_for_AGILE/AGILE"

# Copy finetune script + yaml into AGILE, and patch YAML per split
finetune_py = scripts_dir / "finetune_LNPDB.py"
finetune_yaml_template = scripts_dir / "config_finetune.yaml"

# Ensure files exist
assert finetune_py.exists(), "finetune_LNPDB.py not found in scripts/"
assert finetune_yaml_template.exists(), "config_finetune.yaml not found in scripts/"

# Copy finetune_LNPDB.py into AGILE
shutil.copy(finetune_py, agile_dir / "finetune_LNPDB.py")

# Generate one YAML per split
finetune_config_dir = agile_dir / "finetune"
finetune_config_dir.mkdir(parents=True, exist_ok=True)

for i in range(5):
    yaml_target = finetune_config_dir / f"agile_lnp_hela_cv_{i}.yaml"
    with open(finetune_yaml_template, "r") as f:
        yaml_text = f.read()
    yaml_text = yaml_text.replace(
        "task_name: lnp_hela_with_feat",
        f"task_name: LNPDB_split_{i}"
    )
    with open(yaml_target, "w") as f:
        f.write(yaml_text)

logging.info("finetune_LNPDB.py and split YAMLs prepared in AGILE/")
# Out:
# INFO:root:finetune_LNPDB.py and split YAMLs prepared in AGILE/

# %% [markdown]
# ## 3.2 Finetuning models on respective split train data

# %%
# copy finetune_LNPDB.py from ../LNPDB/data/LNPDB_for_AGILE/scripts into ../LNPDB/data/LNPDB_for_AGILE/AGILE
# also copy yamls in similar manner

# finetune pre-trained AGILE model on 5 cross-validation splits
cv_number_list = [0,1,2,3,4]

for i in cv_number_list:
    yaml_path = agile_dir / f"finetune/agile_lnp_hela_cv_{i}.yaml"
    command = ["python", str(agile_dir / "finetune_LNPDB.py"), str(yaml_path)]
    result = subprocess.run(command, cwd=agile_dir, capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)

# %% [markdown]
# # 4. Generating LNPDB data feature descriptors

# %% [markdown]
# To use the trained models to predict delivery efficacy for new LNP data, LNPDB data has been placed into the folder `LNPDB/data/LNPDB_for_AGILE/LNPDB_data`.
#
# AGILE requires data to be processed into Mordred molecular feature descriptors, which are generated using [repo](https://github.com/mordred-descriptor/mordred) as described in the sixth cell of the notebook. Note that the "descriptors_full" output is from directly generating Mordred descriptors, while the "plus_features" output is with adjustment to required AGILE format. For all LNPDB data included in the paper, this repository already contains the corresponding Mordred descriptors in `LNPDB/data/LNPDB_for_AGILE/LNPDB_data`.
#
# Our Mordred descriptors were validated by comparing generation from AGILE original SMILES and provided fingerprints. The procedure is to generate Mordred descriptors using solely the smiles and Experiment_value columns, and then compare the resulting descriptors with those provided by the AGILE [repo](https://github.com/bowang-lab/AGILE).

# %% [markdown]
# ## 4.1 Generate descriptors

# %%
# Generate Mordred descriptors for heldout datasets and align with known features
def heldout_data(heldout_data_path: str,
                 heldout_data_output_folder: str,
                 known_data_path: str) -> None:
    """
    Generate Mordred descriptors for molecules in heldout_data, then select only
    those features that appear in known_data and append them to the heldout_data.
    Saves both the full descriptor table and the filtered heldout_data to CSV files.

    Parameters:
    - heldout_data_path: path to CSV with columns ['smiles', ...]
    - heldout_data_output_folder: folder to create for output files
    - known_data_path: path to CSV whose columns define the desired features
    """

    df_heldout = pd.read_csv(heldout_data_path)
    logging.info(f"Read heldout data with {len(df_heldout)} molecules.")

    mols = [Chem.MolFromSmiles(smi) for smi in df_heldout['smiles']]
    calc = Calculator(descriptors, ignore_3D=True)
    df_desc = calc.pandas(mols, nproc=1)

    # clean columns
    if isinstance(df_desc.columns, pd.MultiIndex):
        df_desc.columns = [str(name) for name, _ in df_desc.columns]
    else:
        df_desc.columns = [str(c) for c in df_desc.columns]

    df_desc.replace([np.inf, -np.inf], pd.NA, inplace=True)

    if df_desc.isna().sum().sum() > 0:
        logging.warning(f"Detected {df_desc.isna().sum().sum()} NaN or overflow values after descriptor calculation.")

    os.makedirs(heldout_data_output_folder, exist_ok=True)
    dataset_name = Path(heldout_data_path).stem

    desc_full_path = os.path.join(heldout_data_output_folder,
                                  f"{dataset_name}_descriptors_full.csv")
    df_desc.to_csv(desc_full_path, index=False)
    logging.info(f"Full descriptor table saved to {desc_full_path}.")

    df_known = pd.read_csv(known_data_path)
    desired_cols = [col for col in df_known.columns if col.startswith('desc_')]
    logging.info(f"Found {len(desired_cols)} desired desc_* columns in known data.")

    # collect matching columns
    new_features = {}
    missing_features = []
    overflow_features = []
    # Extract feature names from desired columns
    scaling_factor = None
    for col in desired_cols:
        # some features used by AGILE are scaled
        if '/' in col:
            feature_name, scaling_factor = col[len('desc_'):].split('/')
        else:
            feature_name = col[len('desc_'):] 

        if feature_name in df_desc.columns:
            feature_values = df_desc[feature_name]
            printed_flag = [False]
            if feature_values.isna().any():
                logging.warning(f"Feature '{feature_name}' contains NaNs due to overflow during calculation.")
                overflow_features.append(feature_name)
            # else if feature_name == 'MAXssNH' or feature_name == 'MINssNH':
            elif scaling_factor:
                new_features[col] = [
                    safe_div(value, scaling_factor, feature_name, printed_flag)
                    for value in feature_values.values
                ]
            else:
                new_features[col] = [
                    safe_div(value, 1, feature_name, printed_flag)
                    for value in feature_values.values
                ]
            logging.info(f"Added feature column '{col}' from descriptor '{feature_name}'.")
        else:
            # some features used by AGILE are log-Mordred features
            if feature_name == 'log_VR1_A' or feature_name == 'log_VR2_A' or feature_name == 'log_SdssC':
                feature_values = df_desc[f'{feature_name[4:]}']
                if feature_values.isna().any():
                    logging.warning(f"Feature '{feature_name}' contains NaNs due to overflow during calculation.")
                    overflow_features.append(f'log_{feature_name}')
                new_features[col] = [math.log10(value) if value>0 else 0 for value in feature_values.values]
                logging.info(f"Added feature column '{col}' from descriptor '{feature_name}'.")
            else:
                logging.warning(f"Descriptor '{feature_name}' not found in calculated descriptors. Filling NaNs.")
                new_features[col] = [pd.NA] * len(df_heldout)
                missing_features.append(feature_name)

        scaling_factor = None

    df_new_features = pd.DataFrame(new_features)
    df_new_features = df_new_features.reindex(columns=desired_cols)
    df_heldout = pd.concat([df_heldout.reset_index(drop=True),
                            df_new_features.reset_index(drop=True)], axis=1)
    # df_heldout.rename(columns={'IL_SMILES': 'smiles'}, inplace=True)

    # 🔹 Ensure only known features are kept (drop extra Mordred descriptors)
    keep_cols = [c for c in df_heldout.columns if not c.startswith("desc_")] + desired_cols
    df_heldout = df_heldout[keep_cols]

    # concatenate smiles + labels (non-desc_) with filtered descriptors
    non_desc_cols = [c for c in df_heldout.columns if not c.startswith("desc_")]
    df_heldout_final = pd.concat(
        [df_heldout[non_desc_cols].reset_index(drop=True),
         df_new_features.reset_index(drop=True)],
        axis=1
    )

    # Ensure final output columns match the order in known_data
    ref_cols = list(df_known.columns)  # full reference column order
    non_desc_cols = [c for c in df_heldout_final.columns if not c.startswith("desc_")]

    # keep non-desc columns first, then descriptors in reference order
    ordered_cols = non_desc_cols + [c for c in ref_cols if c.startswith("desc_")]

    df_heldout_final = df_heldout_final.reindex(columns=ordered_cols)
    
    heldout_out_path = os.path.join(heldout_data_output_folder, f"{dataset_name}_plus_features.csv")

    df_heldout_final.to_csv(heldout_out_path, index=False)

    logging.info(f"Augmented heldout data (with {len(desired_cols)} descriptors) saved to {heldout_out_path}")

    # Warn about missing features if any
    if missing_features:
        logging.warning(f"{len(missing_features)} features were missing: {missing_features}")

    if overflow_features:
        logging.warning(f"{len(overflow_features)} features contain NaN values due to overflow: {overflow_features}")

# Example call (edit datasets as needed)
heldout_data(
    "../data/LNPDB_for_AGILE/AGILE/data/data/finetuning_set_smiles_plus_features.csv", # only change this argument for each dataset
    "../data/LNPDB_for_AGILE/outputs",
    "../data/LNPDB_for_AGILE/AGILE/data/data/finetuning_set_smiles_plus_features.csv"
)
# Out:
# INFO:root:Read heldout data with 1200 molecules.
# C:\Users\rzhu6\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████████████████████████████████████████████████████████████████████████| 1200/1200 [04:39<00:00,  4.29it/s]
# INFO:root:Full descriptor table saved to ../data/LNPDB_for_AGILE/outputs\finetuning_set_smiles_plus_features_descriptors_full.csv.
# INFO:root:Found 813 desired desc_* columns in known data.
# INFO:root:Added feature column 'desc_ABC/10' from descriptor 'ABC'.
# INFO:root:Added feature column 'desc_ABCGG/10' from descriptor 'ABCGG'.
# INFO:root:Added feature column 'desc_nBase' from descriptor 'nBase'.
# INFO:root:Added feature column 'desc_SpAbs_A/30' from descriptor 'SpAbs_A'.
# INFO:root:Added feature column 'desc_SpMax_A' from descriptor 'SpMax_A'.
# INFO:root:Added feature column 'desc_SpDiam_A' from descriptor 'SpDiam_A'.
# INFO:root:Added feature column 'desc_SpAD_A/30' from descriptor 'SpAD_A'.
# INFO:root:Added feature column 'desc_SpMAD_A' from descriptor 'SpMAD_A'.
# INFO:root:Added feature column 'desc_LogEE_A' from descriptor 'LogEE_A'.
# INFO:root:Added feature column 'desc_VE1_A' from descriptor 'VE1_A'.
# INFO:root:Added feature column 'desc_VE2_A' from descriptor 'VE2_A'.
# INFO:root:Added feature column 'desc_log_VR1_A' from descriptor 'log_VR1_A'.
# INFO:root:Added feature column 'desc_log_VR2_A' from descriptor 'log_VR2_A'.
# INFO:root:Added feature column 'desc_VR3_A/10' from descriptor 'VR3_A'.
# INFO:root:Added feature column 'desc_nAromAtom' from descriptor 'nAromAtom'.
# INFO:root:Added feature column 'desc_nAromBond' from descriptor 'nAromBond'.
# INFO:root:Added feature column 'desc_nAtom/30' from descriptor 'nAtom'.
# INFO:root:Added feature column 'desc_nHeavyAtom/10' from descriptor 'nHeavyAtom'.
# INFO:root:Added feature column 'desc_nHetero' from descriptor 'nHetero'.
# INFO:root:Added feature column 'desc_nH/30' from descriptor 'nH'.
# INFO:root:Added feature column 'desc_nC/10' from descriptor 'nC'.
# INFO:root:Added feature column 'desc_nN' from descriptor 'nN'.
# INFO:root:Added feature column 'desc_ATS0dv/100' from descriptor 'ATS0dv'.
# INFO:root:Added feature column 'desc_ATS1dv/100' from descriptor 'ATS1dv'.
# INFO:root:Added feature column 'desc_ATS2dv/100' from descriptor 'ATS2dv'.
# INFO:root:Added feature column 'desc_ATS3dv/100' from descriptor 'ATS3dv'.
# INFO:root:Added feature column 'desc_ATS4dv/100' from descriptor 'ATS4dv'.
# INFO:root:Added feature column 'desc_ATS5dv/100' from descriptor 'ATS5dv'.
# INFO:root:Added feature column 'desc_ATS6dv/100' from descriptor 'ATS6dv'.
# INFO:root:Added feature column 'desc_ATS7dv/100' from descriptor 'ATS7dv'.
# INFO:root:Added feature column 'desc_ATS0d/100' from descriptor 'ATS0d'.
# INFO:root:Added feature column 'desc_ATS1d/100' from descriptor 'ATS1d'.
# INFO:root:Added feature column 'desc_ATS2d/100' from descriptor 'ATS2d'.
# INFO:root:Added feature column 'desc_ATS3d/100' from descriptor 'ATS3d'.
# INFO:root:Added feature column 'desc_ATS4d/100' from descriptor 'ATS4d'.
# INFO:root:Added feature column 'desc_ATS5d/100' from descriptor 'ATS5d'.
# INFO:root:Added feature column 'desc_ATS6d/100' from descriptor 'ATS6d'.
# INFO:root:Added feature column 'desc_ATS7d/100' from descriptor 'ATS7d'.
# INFO:root:Added feature column 'desc_ATS8d/100' from descriptor 'ATS8d'.
# INFO:root:Added feature column 'desc_ATS0s/100' from descriptor 'ATS0s'.
# INFO:root:Added feature column 'desc_ATS1s/100' from descriptor 'ATS1s'.
# INFO:root:Added feature column 'desc_ATS2s/100' from descriptor 'ATS2s'.
# INFO:root:Added feature column 'desc_ATS3s/100' from descriptor 'ATS3s'.
# INFO:root:Added feature column 'desc_ATS4s/100' from descriptor 'ATS4s'.
# INFO:root:Added feature column 'desc_ATS5s/100' from descriptor 'ATS5s'.
# INFO:root:Added feature column 'desc_ATS6s/100' from descriptor 'ATS6s'.
# INFO:root:Added feature column 'desc_ATS7s/100' from descriptor 'ATS7s'.
# INFO:root:Added feature column 'desc_ATS8s/100' from descriptor 'ATS8s'.
# INFO:root:Added feature column 'desc_ATS0Z/1000' from descriptor 'ATS0Z'.
# INFO:root:Added feature column 'desc_ATS1Z/1000' from descriptor 'ATS1Z'.
# INFO:root:Added feature column 'desc_ATS2Z/1000' from descriptor 'ATS2Z'.
# INFO:root:Added feature column 'desc_ATS3Z/1000' from descriptor 'ATS3Z'.
# INFO:root:Added feature column 'desc_ATS4Z/1000' from descriptor 'ATS4Z'.
# INFO:root:Added feature column 'desc_ATS5Z/1000' from descriptor 'ATS5Z'.
# INFO:root:Added feature column 'desc_ATS6Z/1000' from descriptor 'ATS6Z'.
# INFO:root:Added feature column 'desc_ATS7Z/1000' from descriptor 'ATS7Z'.
# INFO:root:Added feature column 'desc_ATS8Z/1000' from descriptor 'ATS8Z'.
# INFO:root:Added feature column 'desc_ATS0m/1000' from descriptor 'ATS0m'.
# INFO:root:Added feature column 'desc_ATS1m/1000' from descriptor 'ATS1m'.
# INFO:root:Added feature column 'desc_ATS2m/10000' from descriptor 'ATS2m'.
# INFO:root:Added feature column 'desc_ATS3m/10000' from descriptor 'ATS3m'.
# INFO:root:Added feature column 'desc_ATS4m/10000' from descriptor 'ATS4m'.
# INFO:root:Added feature column 'desc_ATS5m/10000' from descriptor 'ATS5m'.
# INFO:root:Added feature column 'desc_ATS6m/10000' from descriptor 'ATS6m'.
# INFO:root:Added feature column 'desc_ATS7m/10000' from descriptor 'ATS7m'.
# INFO:root:Added feature column 'desc_ATS8m/10000' from descriptor 'ATS8m'.
# INFO:root:Added feature column 'desc_ATS0v/10000' from descriptor 'ATS0v'.
# INFO:root:Added feature column 'desc_ATS1v/10000' from descriptor 'ATS1v'.
# INFO:root:Added feature column 'desc_ATS2v/10000' from descriptor 'ATS2v'.
# INFO:root:Added feature column 'desc_ATS3v/10000' from descriptor 'ATS3v'.
# INFO:root:Added feature column 'desc_ATS4v/10000' from descriptor 'ATS4v'.
# INFO:root:Added feature column 'desc_ATS5v/10000' from descriptor 'ATS5v'.
# INFO:root:Added feature column 'desc_ATS6v/10000' from descriptor 'ATS6v'.
# INFO:root:Added feature column 'desc_ATS7v/10000' from descriptor 'ATS7v'.
# INFO:root:Added feature column 'desc_ATS8v/10000' from descriptor 'ATS8v'.
# INFO:root:Added feature column 'desc_ATS0se/100' from descriptor 'ATS0se'.
# INFO:root:Added feature column 'desc_ATS1se/1000' from descriptor 'ATS1se'.
# INFO:root:Added feature column 'desc_ATS2se/1000' from descriptor 'ATS2se'.
# INFO:root:Added feature column 'desc_ATS3se/1000' from descriptor 'ATS3se'.
# INFO:root:Added feature column 'desc_ATS4se/1000' from descriptor 'ATS4se'.
# INFO:root:Added feature column 'desc_ATS5se/1000' from descriptor 'ATS5se'.
# INFO:root:Added feature column 'desc_ATS6se/1000' from descriptor 'ATS6se'.
# INFO:root:Added feature column 'desc_ATS7se/1000' from descriptor 'ATS7se'.
# INFO:root:Added feature column 'desc_ATS8se/1000' from descriptor 'ATS8se'.
# INFO:root:Added feature column 'desc_ATS0pe/100' from descriptor 'ATS0pe'.
# INFO:root:Added feature column 'desc_ATS1pe/100' from descriptor 'ATS1pe'.
# INFO:root:Added feature column 'desc_ATS2pe/1000' from descriptor 'ATS2pe'.
# INFO:root:Added feature column 'desc_ATS3pe/1000' from descriptor 'ATS3pe'.
# INFO:root:Added feature column 'desc_ATS4pe/1000' from descriptor 'ATS4pe'.
# INFO:root:Added feature column 'desc_ATS5pe/1000' from descriptor 'ATS5pe'.
# INFO:root:Added feature column 'desc_ATS6pe/1000' from descriptor 'ATS6pe'.
# INFO:root:Added feature column 'desc_ATS7pe/1000' from descriptor 'ATS7pe'.
# INFO:root:Added feature column 'desc_ATS8pe/1000' from descriptor 'ATS8pe'.
# INFO:root:Added feature column 'desc_ATS0are/100' from descriptor 'ATS0are'.
# INFO:root:Added feature column 'desc_ATS1are/100' from descriptor 'ATS1are'.
# INFO:root:Added feature column 'desc_ATS2are/1000' from descriptor 'ATS2are'.
# INFO:root:Added feature column 'desc_ATS3are/1000' from descriptor 'ATS3are'.
# INFO:root:Added feature column 'desc_ATS4are/1000' from descriptor 'ATS4are'.
# INFO:root:Added feature column 'desc_ATS5are/1000' from descriptor 'ATS5are'.
# INFO:root:Added feature column 'desc_ATS6are/1000' from descriptor 'ATS6are'.
# INFO:root:Added feature column 'desc_ATS7are/1000' from descriptor 'ATS7are'.
# INFO:root:Added feature column 'desc_ATS8are/1000' from descriptor 'ATS8are'.
# INFO:root:Added feature column 'desc_ATS0p/30' from descriptor 'ATS0p'.
# INFO:root:Added feature column 'desc_ATS1p/100' from descriptor 'ATS1p'.
# INFO:root:Added feature column 'desc_ATS2p/100' from descriptor 'ATS2p'.
# INFO:root:Added feature column 'desc_ATS3p/100' from descriptor 'ATS3p'.
# INFO:root:Added feature column 'desc_ATS4p/100' from descriptor 'ATS4p'.
# INFO:root:Added feature column 'desc_ATS5p/100' from descriptor 'ATS5p'.
# INFO:root:Added feature column 'desc_ATS6p/100' from descriptor 'ATS6p'.
# INFO:root:Added feature column 'desc_ATS7p/100' from descriptor 'ATS7p'.
# INFO:root:Added feature column 'desc_ATS8p/100' from descriptor 'ATS8p'.
# INFO:root:Added feature column 'desc_ATS0i/10000' from descriptor 'ATS0i'.
# INFO:root:Added feature column 'desc_ATS1i/10000' from descriptor 'ATS1i'.
# INFO:root:Added feature column 'desc_ATS2i/10000' from descriptor 'ATS2i'.
# INFO:root:Added feature column 'desc_ATS3i/10000' from descriptor 'ATS3i'.
# INFO:root:Added feature column 'desc_ATS4i/10000' from descriptor 'ATS4i'.
# INFO:root:Added feature column 'desc_ATS5i/10000' from descriptor 'ATS5i'.
# INFO:root:Added feature column 'desc_ATS6i/10000' from descriptor 'ATS6i'.
# INFO:root:Added feature column 'desc_ATS7i/10000' from descriptor 'ATS7i'.
# INFO:root:Added feature column 'desc_ATS8i/10000' from descriptor 'ATS8i'.
# INFO:root:Added feature column 'desc_AATS0dv' from descriptor 'AATS0dv'.
# INFO:root:Added feature column 'desc_AATS1dv' from descriptor 'AATS1dv'.
# INFO:root:Added feature column 'desc_AATS2dv' from descriptor 'AATS2dv'.
# INFO:root:Added feature column 'desc_AATS3dv' from descriptor 'AATS3dv'.
# INFO:root:Added feature column 'desc_AATS4dv' from descriptor 'AATS4dv'.
# INFO:root:Added feature column 'desc_AATS5dv' from descriptor 'AATS5dv'.
# INFO:root:Added feature column 'desc_AATS6dv' from descriptor 'AATS6dv'.
# INFO:root:Added feature column 'desc_AATS8dv' from descriptor 'AATS8dv'.
# INFO:root:Added feature column 'desc_AATS0d' from descriptor 'AATS0d'.
# INFO:root:Added feature column 'desc_AATS1d' from descriptor 'AATS1d'.
# INFO:root:Added feature column 'desc_AATS2d' from descriptor 'AATS2d'.
# INFO:root:Added feature column 'desc_AATS3d' from descriptor 'AATS3d'.
# INFO:root:Added feature column 'desc_AATS4d' from descriptor 'AATS4d'.
# INFO:root:Added feature column 'desc_AATS5d' from descriptor 'AATS5d'.
# INFO:root:Added feature column 'desc_AATS6d' from descriptor 'AATS6d'.
# INFO:root:Added feature column 'desc_AATS7d' from descriptor 'AATS7d'.
# INFO:root:Added feature column 'desc_AATS5s' from descriptor 'AATS5s'.
# INFO:root:Added feature column 'desc_AATS6s' from descriptor 'AATS6s'.
# INFO:root:Added feature column 'desc_AATS0Z/10' from descriptor 'AATS0Z'.
# INFO:root:Added feature column 'desc_AATS1Z/10' from descriptor 'AATS1Z'.
# INFO:root:Added feature column 'desc_AATS2Z/10' from descriptor 'AATS2Z'.
# INFO:root:Added feature column 'desc_AATS3Z' from descriptor 'AATS3Z'.
# INFO:root:Added feature column 'desc_AATS4Z' from descriptor 'AATS4Z'.
# INFO:root:Added feature column 'desc_AATS5Z' from descriptor 'AATS5Z'.
# INFO:root:Added feature column 'desc_AATS6Z' from descriptor 'AATS6Z'.
# INFO:root:Added feature column 'desc_AATS8Z' from descriptor 'AATS8Z'.
# INFO:root:Added feature column 'desc_AATS0m/10' from descriptor 'AATS0m'.
# INFO:root:Added feature column 'desc_AATS1m/30' from descriptor 'AATS1m'.
# INFO:root:Added feature column 'desc_AATS2m/10' from descriptor 'AATS2m'.
# INFO:root:Added feature column 'desc_AATS3m/10' from descriptor 'AATS3m'.
# INFO:root:Added feature column 'desc_AATS4m/10' from descriptor 'AATS4m'.
# INFO:root:Added feature column 'desc_AATS5m/10' from descriptor 'AATS5m'.
# INFO:root:Added feature column 'desc_AATS6m/10' from descriptor 'AATS6m'.
# INFO:root:Added feature column 'desc_AATS8m/10' from descriptor 'AATS8m'.
# INFO:root:Added feature column 'desc_AATS0v/30' from descriptor 'AATS0v'.
# INFO:root:Added feature column 'desc_AATS1v/100' from descriptor 'AATS1v'.
# INFO:root:Added feature column 'desc_AATS2v/30' from descriptor 'AATS2v'.
# INFO:root:Added feature column 'desc_AATS3v/30' from descriptor 'AATS3v'.
# INFO:root:Added feature column 'desc_AATS4v/30' from descriptor 'AATS4v'.
# INFO:root:Added feature column 'desc_AATS5v/30' from descriptor 'AATS5v'.
# INFO:root:Added feature column 'desc_AATS6v/30' from descriptor 'AATS6v'.
# INFO:root:Added feature column 'desc_AATS7v/30' from descriptor 'AATS7v'.
# INFO:root:Added feature column 'desc_AATS5se' from descriptor 'AATS5se'.
# INFO:root:Added feature column 'desc_AATS6se' from descriptor 'AATS6se'.
# INFO:root:Added feature column 'desc_AATS5pe' from descriptor 'AATS5pe'.
# INFO:root:Added feature column 'desc_AATS5are' from descriptor 'AATS5are'.
# INFO:root:Added feature column 'desc_AATS6are' from descriptor 'AATS6are'.
# INFO:root:Added feature column 'desc_AATS0p' from descriptor 'AATS0p'.
# INFO:root:Added feature column 'desc_AATS1p' from descriptor 'AATS1p'.
# INFO:root:Added feature column 'desc_AATS2p' from descriptor 'AATS2p'.
# INFO:root:Added feature column 'desc_AATS3p' from descriptor 'AATS3p'.
# INFO:root:Added feature column 'desc_AATS4p' from descriptor 'AATS4p'.
# INFO:root:Added feature column 'desc_AATS5p' from descriptor 'AATS5p'.
# INFO:root:Added feature column 'desc_AATS6p' from descriptor 'AATS6p'.
# INFO:root:Added feature column 'desc_AATS7p' from descriptor 'AATS7p'.
# INFO:root:Added feature column 'desc_AATS8p' from descriptor 'AATS8p'.
# INFO:root:Added feature column 'desc_AATS0i/30' from descriptor 'AATS0i'.
# INFO:root:Added feature column 'desc_AATS1i/30' from descriptor 'AATS1i'.
# INFO:root:Added feature column 'desc_AATS2i/30' from descriptor 'AATS2i'.
# INFO:root:Added feature column 'desc_AATS5i/30' from descriptor 'AATS5i'.
# INFO:root:Added feature column 'desc_AATS6i/30' from descriptor 'AATS6i'.
# INFO:root:Added feature column 'desc_AATS7i/30' from descriptor 'AATS7i'.
# INFO:root:Added feature column 'desc_AATS8i/30' from descriptor 'AATS8i'.
# INFO:root:Added feature column 'desc_ATSC0c' from descriptor 'ATSC0c'.
# INFO:root:Added feature column 'desc_ATSC1c' from descriptor 'ATSC1c'.
# INFO:root:Added feature column 'desc_ATSC5c' from descriptor 'ATSC5c'.
# INFO:root:Added feature column 'desc_ATSC8c' from descriptor 'ATSC8c'.
# INFO:root:Added feature column 'desc_ATSC0dv/100' from descriptor 'ATSC0dv'.
# INFO:root:Added feature column 'desc_ATSC1dv/30' from descriptor 'ATSC1dv'.
# INFO:root:Added feature column 'desc_ATSC2dv/30' from descriptor 'ATSC2dv'.
# INFO:root:Added feature column 'desc_ATSC4dv/10' from descriptor 'ATSC4dv'.
# INFO:root:Added feature column 'desc_ATSC5dv/10' from descriptor 'ATSC5dv'.
# INFO:root:Added feature column 'desc_ATSC7dv/30' from descriptor 'ATSC7dv'.
# INFO:root:Added feature column 'desc_ATSC8dv/10' from descriptor 'ATSC8dv'.
# INFO:root:Added feature column 'desc_ATSC0d/10' from descriptor 'ATSC0d'.
# INFO:root:Added feature column 'desc_ATSC2d/10' from descriptor 'ATSC2d'.
# INFO:root:Added feature column 'desc_ATSC6d' from descriptor 'ATSC6d'.
# INFO:root:Added feature column 'desc_ATSC7d' from descriptor 'ATSC7d'.
# INFO:root:Added feature column 'desc_ATSC0s/30' from descriptor 'ATSC0s'.
# INFO:root:Added feature column 'desc_ATSC1s' from descriptor 'ATSC1s'.
# INFO:root:Added feature column 'desc_ATSC2s/10' from descriptor 'ATSC2s'.
# INFO:root:Added feature column 'desc_ATSC5s/10' from descriptor 'ATSC5s'.
# INFO:root:Added feature column 'desc_ATSC7s/10' from descriptor 'ATSC7s'.
# INFO:root:Added feature column 'desc_ATSC8s/10' from descriptor 'ATSC8s'.
# INFO:root:Added feature column 'desc_ATSC0Z/100' from descriptor 'ATSC0Z'.
# INFO:root:Added feature column 'desc_ATSC1Z/10' from descriptor 'ATSC1Z'.
# INFO:root:Added feature column 'desc_ATSC2Z/100' from descriptor 'ATSC2Z'.
# INFO:root:Added feature column 'desc_ATSC4Z/30' from descriptor 'ATSC4Z'.
# INFO:root:Added feature column 'desc_ATSC7Z/30' from descriptor 'ATSC7Z'.
# INFO:root:Added feature column 'desc_ATSC8Z/30' from descriptor 'ATSC8Z'.
# INFO:root:Added feature column 'desc_ATSC0m/1000' from descriptor 'ATSC0m'.
# INFO:root:Added feature column 'desc_ATSC1m/30' from descriptor 'ATSC1m'.
# INFO:root:Added feature column 'desc_ATSC2m/1000' from descriptor 'ATSC2m'.
# INFO:root:Added feature column 'desc_ATSC4m/100' from descriptor 'ATSC4m'.
# INFO:root:Added feature column 'desc_ATSC7m/100' from descriptor 'ATSC7m'.
# INFO:root:Added feature column 'desc_ATSC8m/100' from descriptor 'ATSC8m'.
# INFO:root:Added feature column 'desc_ATSC0v/1000' from descriptor 'ATSC0v'.
# INFO:root:Added feature column 'desc_ATSC1v/100' from descriptor 'ATSC1v'.
# INFO:root:Added feature column 'desc_ATSC2v/1000' from descriptor 'ATSC2v'.
# INFO:root:Added feature column 'desc_ATSC4v/100' from descriptor 'ATSC4v'.
# INFO:root:Added feature column 'desc_ATSC7v/100' from descriptor 'ATSC7v'.
# INFO:root:Added feature column 'desc_ATSC8v/100' from descriptor 'ATSC8v'.
# INFO:root:Added feature column 'desc_ATSC1se' from descriptor 'ATSC1se'.
# INFO:root:Added feature column 'desc_ATSC2se' from descriptor 'ATSC2se'.
# INFO:root:Added feature column 'desc_ATSC5se' from descriptor 'ATSC5se'.
# INFO:root:Added feature column 'desc_ATSC7se' from descriptor 'ATSC7se'.
# INFO:root:Added feature column 'desc_ATSC0pe' from descriptor 'ATSC0pe'.
# INFO:root:Added feature column 'desc_ATSC1pe' from descriptor 'ATSC1pe'.
# INFO:root:Added feature column 'desc_ATSC2pe' from descriptor 'ATSC2pe'.
# INFO:root:Added feature column 'desc_ATSC5pe' from descriptor 'ATSC5pe'.
# INFO:root:Added feature column 'desc_ATSC7pe' from descriptor 'ATSC7pe'.
# INFO:root:Added feature column 'desc_ATSC8pe' from descriptor 'ATSC8pe'.
# INFO:root:Added feature column 'desc_ATSC0are' from descriptor 'ATSC0are'.
# INFO:root:Added feature column 'desc_ATSC1are' from descriptor 'ATSC1are'.
# INFO:root:Added feature column 'desc_ATSC2are' from descriptor 'ATSC2are'.
# INFO:root:Added feature column 'desc_ATSC5are' from descriptor 'ATSC5are'.
# INFO:root:Added feature column 'desc_ATSC7are' from descriptor 'ATSC7are'.
# INFO:root:Added feature column 'desc_ATSC8are' from descriptor 'ATSC8are'.
# INFO:root:Added feature column 'desc_ATSC0p/10' from descriptor 'ATSC0p'.
# INFO:root:Added feature column 'desc_ATSC1p' from descriptor 'ATSC1p'.
# INFO:root:Added feature column 'desc_ATSC2p/10' from descriptor 'ATSC2p'.
# INFO:root:Added feature column 'desc_ATSC5p' from descriptor 'ATSC5p'.
# INFO:root:Added feature column 'desc_ATSC7p' from descriptor 'ATSC7p'.
# INFO:root:Added feature column 'desc_ATSC0i/30' from descriptor 'ATSC0i'.
# INFO:root:Added feature column 'desc_ATSC1i/10' from descriptor 'ATSC1i'.
# INFO:root:Added feature column 'desc_ATSC2i/30' from descriptor 'ATSC2i'.
# INFO:root:Added feature column 'desc_ATSC5i/10' from descriptor 'ATSC5i'.
# INFO:root:Added feature column 'desc_ATSC8i/10' from descriptor 'ATSC8i'.
# INFO:root:Added feature column 'desc_AATSC4c' from descriptor 'AATSC4c'.
# INFO:root:Added feature column 'desc_AATSC5c' from descriptor 'AATSC5c'.
# INFO:root:Added feature column 'desc_AATSC8c' from descriptor 'AATSC8c'.
# INFO:root:Added feature column 'desc_AATSC0dv' from descriptor 'AATSC0dv'.
# INFO:root:Added feature column 'desc_AATSC1dv' from descriptor 'AATSC1dv'.
# INFO:root:Added feature column 'desc_AATSC2dv' from descriptor 'AATSC2dv'.
# INFO:root:Added feature column 'desc_AATSC4dv' from descriptor 'AATSC4dv'.
# INFO:root:Added feature column 'desc_AATSC5dv' from descriptor 'AATSC5dv'.
# INFO:root:Added feature column 'desc_AATSC7dv' from descriptor 'AATSC7dv'.
# INFO:root:Added feature column 'desc_AATSC8dv' from descriptor 'AATSC8dv'.
# INFO:root:Added feature column 'desc_AATSC2d' from descriptor 'AATSC2d'.
# INFO:root:Added feature column 'desc_AATSC6d' from descriptor 'AATSC6d'.
# INFO:root:Added feature column 'desc_AATSC7d' from descriptor 'AATSC7d'.
# INFO:root:Added feature column 'desc_AATSC1s' from descriptor 'AATSC1s'.
# INFO:root:Added feature column 'desc_AATSC2s' from descriptor 'AATSC2s'.
# INFO:root:Added feature column 'desc_AATSC3s' from descriptor 'AATSC3s'.
# INFO:root:Added feature column 'desc_AATSC5s' from descriptor 'AATSC5s'.
# INFO:root:Added feature column 'desc_AATSC8s' from descriptor 'AATSC8s'.
# INFO:root:Added feature column 'desc_AATSC1Z' from descriptor 'AATSC1Z'.
# INFO:root:Added feature column 'desc_AATSC2Z' from descriptor 'AATSC2Z'.
# INFO:root:Added feature column 'desc_AATSC4Z' from descriptor 'AATSC4Z'.
# INFO:root:Added feature column 'desc_AATSC7Z' from descriptor 'AATSC7Z'.
# INFO:root:Added feature column 'desc_AATSC8Z' from descriptor 'AATSC8Z'.
# INFO:root:Added feature column 'desc_AATSC1m' from descriptor 'AATSC1m'.
# INFO:root:Added feature column 'desc_AATSC2m' from descriptor 'AATSC2m'.
# INFO:root:Added feature column 'desc_AATSC4m' from descriptor 'AATSC4m'.
# INFO:root:Added feature column 'desc_AATSC7m' from descriptor 'AATSC7m'.
# INFO:root:Added feature column 'desc_AATSC8m' from descriptor 'AATSC8m'.
# INFO:root:Added feature column 'desc_AATSC0v/10' from descriptor 'AATSC0v'.
# INFO:root:Added feature column 'desc_AATSC1v' from descriptor 'AATSC1v'.
# INFO:root:Added feature column 'desc_AATSC2v/10' from descriptor 'AATSC2v'.
# INFO:root:Added feature column 'desc_AATSC4v' from descriptor 'AATSC4v'.
# INFO:root:Added feature column 'desc_AATSC5v' from descriptor 'AATSC5v'.
# INFO:root:Added feature column 'desc_AATSC7v' from descriptor 'AATSC7v'.
# INFO:root:Added feature column 'desc_AATSC8v' from descriptor 'AATSC8v'.
# INFO:root:Added feature column 'desc_AATSC0se' from descriptor 'AATSC0se'.
# INFO:root:Added feature column 'desc_AATSC1se' from descriptor 'AATSC1se'.
# INFO:root:Added feature column 'desc_AATSC2se' from descriptor 'AATSC2se'.
# INFO:root:Added feature column 'desc_AATSC3se' from descriptor 'AATSC3se'.
# INFO:root:Added feature column 'desc_AATSC7se' from descriptor 'AATSC7se'.
# INFO:root:Added feature column 'desc_AATSC8se' from descriptor 'AATSC8se'.
# INFO:root:Added feature column 'desc_AATSC1pe' from descriptor 'AATSC1pe'.
# INFO:root:Added feature column 'desc_AATSC2pe' from descriptor 'AATSC2pe'.
# INFO:root:Added feature column 'desc_AATSC3pe' from descriptor 'AATSC3pe'.
# INFO:root:Added feature column 'desc_AATSC7pe' from descriptor 'AATSC7pe'.
# INFO:root:Added feature column 'desc_AATSC8pe' from descriptor 'AATSC8pe'.
# INFO:root:Added feature column 'desc_AATSC1are' from descriptor 'AATSC1are'.
# INFO:root:Added feature column 'desc_AATSC2are' from descriptor 'AATSC2are'.
# INFO:root:Added feature column 'desc_AATSC3are' from descriptor 'AATSC3are'.
# INFO:root:Added feature column 'desc_AATSC7are' from descriptor 'AATSC7are'.
# INFO:root:Added feature column 'desc_AATSC8are' from descriptor 'AATSC8are'.
# INFO:root:Added feature column 'desc_AATSC0p' from descriptor 'AATSC0p'.
# INFO:root:Added feature column 'desc_AATSC1p' from descriptor 'AATSC1p'.
# INFO:root:Added feature column 'desc_AATSC2p' from descriptor 'AATSC2p'.
# INFO:root:Added feature column 'desc_AATSC5p' from descriptor 'AATSC5p'.
# INFO:root:Added feature column 'desc_AATSC0i' from descriptor 'AATSC0i'.
# INFO:root:Added feature column 'desc_AATSC1i' from descriptor 'AATSC1i'.
# INFO:root:Added feature column 'desc_AATSC2i' from descriptor 'AATSC2i'.
# INFO:root:Added feature column 'desc_AATSC5i' from descriptor 'AATSC5i'.
# INFO:root:Added feature column 'desc_AATSC8i' from descriptor 'AATSC8i'.
# INFO:root:Added feature column 'desc_MATS4c' from descriptor 'MATS4c'.
# INFO:root:Added feature column 'desc_MATS5c' from descriptor 'MATS5c'.
# INFO:root:Added feature column 'desc_MATS8c' from descriptor 'MATS8c'.
# INFO:root:Added feature column 'desc_MATS1dv' from descriptor 'MATS1dv'.
# INFO:root:Added feature column 'desc_MATS2dv' from descriptor 'MATS2dv'.
# INFO:root:Added feature column 'desc_MATS4dv' from descriptor 'MATS4dv'.
# INFO:root:Added feature column 'desc_MATS5dv' from descriptor 'MATS5dv'.
# INFO:root:Added feature column 'desc_MATS7dv' from descriptor 'MATS7dv'.
# INFO:root:Added feature column 'desc_MATS8dv' from descriptor 'MATS8dv'.
# INFO:root:Added feature column 'desc_MATS2d' from descriptor 'MATS2d'.
# INFO:root:Added feature column 'desc_MATS6d' from descriptor 'MATS6d'.
# INFO:root:Added feature column 'desc_MATS7d' from descriptor 'MATS7d'.
# INFO:root:Added feature column 'desc_MATS1s' from descriptor 'MATS1s'.
# INFO:root:Added feature column 'desc_MATS2s' from descriptor 'MATS2s'.
# INFO:root:Added feature column 'desc_MATS5s' from descriptor 'MATS5s'.
# INFO:root:Added feature column 'desc_MATS7s' from descriptor 'MATS7s'.
# INFO:root:Added feature column 'desc_MATS8s' from descriptor 'MATS8s'.
# INFO:root:Added feature column 'desc_MATS1Z' from descriptor 'MATS1Z'.
# INFO:root:Added feature column 'desc_MATS2Z' from descriptor 'MATS2Z'.
# INFO:root:Added feature column 'desc_MATS4Z' from descriptor 'MATS4Z'.
# INFO:root:Added feature column 'desc_MATS7Z' from descriptor 'MATS7Z'.
# INFO:root:Added feature column 'desc_MATS8Z' from descriptor 'MATS8Z'.
# INFO:root:Added feature column 'desc_MATS1m' from descriptor 'MATS1m'.
# INFO:root:Added feature column 'desc_MATS2m' from descriptor 'MATS2m'.
# INFO:root:Added feature column 'desc_MATS4m' from descriptor 'MATS4m'.
# INFO:root:Added feature column 'desc_MATS7m' from descriptor 'MATS7m'.
# INFO:root:Added feature column 'desc_MATS8m' from descriptor 'MATS8m'.
# INFO:root:Added feature column 'desc_MATS1v' from descriptor 'MATS1v'.
# INFO:root:Added feature column 'desc_MATS2v' from descriptor 'MATS2v'.
# INFO:root:Added feature column 'desc_MATS4v' from descriptor 'MATS4v'.
# INFO:root:Added feature column 'desc_MATS5v' from descriptor 'MATS5v'.
# INFO:root:Added feature column 'desc_MATS7v' from descriptor 'MATS7v'.
# INFO:root:Added feature column 'desc_MATS8v' from descriptor 'MATS8v'.
# INFO:root:Added feature column 'desc_MATS1se' from descriptor 'MATS1se'.
# INFO:root:Added feature column 'desc_MATS2se' from descriptor 'MATS2se'.
# INFO:root:Added feature column 'desc_MATS7se' from descriptor 'MATS7se'.
# INFO:root:Added feature column 'desc_MATS8se' from descriptor 'MATS8se'.
# INFO:root:Added feature column 'desc_MATS1pe' from descriptor 'MATS1pe'.
# INFO:root:Added feature column 'desc_MATS2pe' from descriptor 'MATS2pe'.
# INFO:root:Added feature column 'desc_MATS7pe' from descriptor 'MATS7pe'.
# INFO:root:Added feature column 'desc_MATS8pe' from descriptor 'MATS8pe'.
# INFO:root:Added feature column 'desc_MATS1are' from descriptor 'MATS1are'.
# INFO:root:Added feature column 'desc_MATS2are' from descriptor 'MATS2are'.
# INFO:root:Added feature column 'desc_MATS7are' from descriptor 'MATS7are'.
# INFO:root:Added feature column 'desc_MATS8are' from descriptor 'MATS8are'.
# INFO:root:Added feature column 'desc_MATS1p' from descriptor 'MATS1p'.
# INFO:root:Added feature column 'desc_MATS2p' from descriptor 'MATS2p'.
# INFO:root:Added feature column 'desc_MATS5p' from descriptor 'MATS5p'.
# INFO:root:Added feature column 'desc_MATS1i' from descriptor 'MATS1i'.
# INFO:root:Added feature column 'desc_MATS2i' from descriptor 'MATS2i'.
# INFO:root:Added feature column 'desc_MATS5i' from descriptor 'MATS5i'.
# INFO:root:Added feature column 'desc_MATS8i' from descriptor 'MATS8i'.
# INFO:root:Added feature column 'desc_GATS1c' from descriptor 'GATS1c'.
# INFO:root:Added feature column 'desc_GATS2c' from descriptor 'GATS2c'.
# INFO:root:Added feature column 'desc_GATS4c' from descriptor 'GATS4c'.
# INFO:root:Added feature column 'desc_GATS6c' from descriptor 'GATS6c'.
# INFO:root:Added feature column 'desc_GATS7c' from descriptor 'GATS7c'.
# INFO:root:Added feature column 'desc_GATS1dv' from descriptor 'GATS1dv'.
# INFO:root:Added feature column 'desc_GATS2dv' from descriptor 'GATS2dv'.
# INFO:root:Added feature column 'desc_GATS7dv' from descriptor 'GATS7dv'.
# INFO:root:Added feature column 'desc_GATS1d' from descriptor 'GATS1d'.
# INFO:root:Added feature column 'desc_GATS2d' from descriptor 'GATS2d'.
# INFO:root:Added feature column 'desc_GATS6d' from descriptor 'GATS6d'.
# INFO:root:Added feature column 'desc_GATS8d' from descriptor 'GATS8d'.
# INFO:root:Added feature column 'desc_GATS1s' from descriptor 'GATS1s'.
# INFO:root:Added feature column 'desc_GATS2s' from descriptor 'GATS2s'.
# INFO:root:Added feature column 'desc_GATS7s' from descriptor 'GATS7s'.
# INFO:root:Added feature column 'desc_GATS1Z' from descriptor 'GATS1Z'.
# INFO:root:Added feature column 'desc_GATS2Z' from descriptor 'GATS2Z'.
# INFO:root:Added feature column 'desc_GATS7Z' from descriptor 'GATS7Z'.
# INFO:root:Added feature column 'desc_GATS8Z' from descriptor 'GATS8Z'.
# INFO:root:Added feature column 'desc_GATS1m' from descriptor 'GATS1m'.
# INFO:root:Added feature column 'desc_GATS2m' from descriptor 'GATS2m'.
# INFO:root:Added feature column 'desc_GATS7m' from descriptor 'GATS7m'.
# INFO:root:Added feature column 'desc_GATS8m' from descriptor 'GATS8m'.
# INFO:root:Added feature column 'desc_GATS1v' from descriptor 'GATS1v'.
# INFO:root:Added feature column 'desc_GATS2v' from descriptor 'GATS2v'.
# INFO:root:Added feature column 'desc_GATS3v' from descriptor 'GATS3v'.
# INFO:root:Added feature column 'desc_GATS5v' from descriptor 'GATS5v'.
# INFO:root:Added feature column 'desc_GATS8v' from descriptor 'GATS8v'.
# INFO:root:Added feature column 'desc_GATS1se' from descriptor 'GATS1se'.
# INFO:root:Added feature column 'desc_GATS2se' from descriptor 'GATS2se'.
# INFO:root:Added feature column 'desc_GATS7se' from descriptor 'GATS7se'.
# INFO:root:Added feature column 'desc_GATS1pe' from descriptor 'GATS1pe'.
# INFO:root:Added feature column 'desc_GATS2pe' from descriptor 'GATS2pe'.
# INFO:root:Added feature column 'desc_GATS6pe' from descriptor 'GATS6pe'.
# INFO:root:Added feature column 'desc_GATS7pe' from descriptor 'GATS7pe'.
# INFO:root:Added feature column 'desc_GATS1are' from descriptor 'GATS1are'.
# INFO:root:Added feature column 'desc_GATS2are' from descriptor 'GATS2are'.
# INFO:root:Added feature column 'desc_GATS6are' from descriptor 'GATS6are'.
# INFO:root:Added feature column 'desc_GATS7are' from descriptor 'GATS7are'.
# INFO:root:Added feature column 'desc_GATS1p' from descriptor 'GATS1p'.
# INFO:root:Added feature column 'desc_GATS3p' from descriptor 'GATS3p'.
# INFO:root:Added feature column 'desc_GATS5p' from descriptor 'GATS5p'.
# INFO:root:Added feature column 'desc_GATS1i' from descriptor 'GATS1i'.
# INFO:root:Added feature column 'desc_GATS5i' from descriptor 'GATS5i'.
# INFO:root:Added feature column 'desc_GATS8i' from descriptor 'GATS8i'.
# INFO:root:Added feature column 'desc_BCUTd-1h' from descriptor 'BCUTd-1h'.
# INFO:root:Added feature column 'desc_BCUTd-1l' from descriptor 'BCUTd-1l'.
# INFO:root:Added feature column 'desc_BCUTs-1h' from descriptor 'BCUTs-1h'.
# INFO:root:Added feature column 'desc_BCUTs-1l' from descriptor 'BCUTs-1l'.
# INFO:root:Added feature column 'desc_BCUTZ-1l' from descriptor 'BCUTZ-1l'.
# INFO:root:Added feature column 'desc_BCUTm-1l/10' from descriptor 'BCUTm-1l'.
# INFO:root:Added feature column 'desc_BCUTv-1h/10' from descriptor 'BCUTv-1h'.
# INFO:root:Added feature column 'desc_BCUTse-1h' from descriptor 'BCUTse-1h'.
# INFO:root:Added feature column 'desc_BCUTse-1l' from descriptor 'BCUTse-1l'.
# INFO:root:Added feature column 'desc_BCUTpe-1h' from descriptor 'BCUTpe-1h'.
# INFO:root:Added feature column 'desc_BCUTpe-1l' from descriptor 'BCUTpe-1l'.
# INFO:root:Added feature column 'desc_BCUTare-1l' from descriptor 'BCUTare-1l'.
# INFO:root:Added feature column 'desc_BCUTp-1h' from descriptor 'BCUTp-1h'.
# INFO:root:Added feature column 'desc_BCUTp-1l' from descriptor 'BCUTp-1l'.
# INFO:root:Added feature column 'desc_BCUTi-1h/10' from descriptor 'BCUTi-1h'.
# INFO:root:Added feature column 'desc_BCUTi-1l/10' from descriptor 'BCUTi-1l'.
# INFO:root:Added feature column 'desc_BalabanJ' from descriptor 'BalabanJ'.
# INFO:root:Added feature column 'desc_SpAbs_DzZ/1000' from descriptor 'SpAbs_DzZ'.
# INFO:root:Added feature column 'desc_SpMax_DzZ/100' from descriptor 'SpMax_DzZ'.
# INFO:root:Added feature column 'desc_SpDiam_DzZ/100' from descriptor 'SpDiam_DzZ'.
# INFO:root:Added feature column 'desc_SpAD_DzZ/1000' from descriptor 'SpAD_DzZ'.
# INFO:root:Added feature column 'desc_SpMAD_DzZ/10' from descriptor 'SpMAD_DzZ'.
# INFO:root:Added feature column 'desc_LogEE_DzZ/100' from descriptor 'LogEE_DzZ'.
# INFO:root:Added feature column 'desc_VE1_DzZ' from descriptor 'VE1_DzZ'.
# INFO:root:Added feature column 'desc_VE2_DzZ' from descriptor 'VE2_DzZ'.
# INFO:root:Added feature column 'desc_VE3_DzZ' from descriptor 'VE3_DzZ'.
# INFO:root:Added feature column 'desc_VR1_DzZ/100' from descriptor 'VR1_DzZ'.
# INFO:root:Added feature column 'desc_VR2_DzZ' from descriptor 'VR2_DzZ'.
# INFO:root:Added feature column 'desc_VR3_DzZ' from descriptor 'VR3_DzZ'.
# INFO:root:Added feature column 'desc_SpAbs_Dzm/1000' from descriptor 'SpAbs_Dzm'.
# INFO:root:Added feature column 'desc_SpMax_Dzm/100' from descriptor 'SpMax_Dzm'.
# INFO:root:Added feature column 'desc_SpDiam_Dzm/100' from descriptor 'SpDiam_Dzm'.
# INFO:root:Added feature column 'desc_SpAD_Dzm/1000' from descriptor 'SpAD_Dzm'.
# INFO:root:Added feature column 'desc_SpMAD_Dzm/10' from descriptor 'SpMAD_Dzm'.
# INFO:root:Added feature column 'desc_LogEE_Dzm/100' from descriptor 'LogEE_Dzm'.
# INFO:root:Added feature column 'desc_VE1_Dzm' from descriptor 'VE1_Dzm'.
# INFO:root:Added feature column 'desc_VE2_Dzm' from descriptor 'VE2_Dzm'.
# INFO:root:Added feature column 'desc_VE3_Dzm' from descriptor 'VE3_Dzm'.
# INFO:root:Added feature column 'desc_VR1_Dzm/100' from descriptor 'VR1_Dzm'.
# INFO:root:Added feature column 'desc_VR2_Dzm' from descriptor 'VR2_Dzm'.
# INFO:root:Added feature column 'desc_VR3_Dzm' from descriptor 'VR3_Dzm'.
# INFO:root:Added feature column 'desc_SpAbs_Dzv/1000' from descriptor 'SpAbs_Dzv'.
# INFO:root:Added feature column 'desc_SpMax_Dzv/100' from descriptor 'SpMax_Dzv'.
# INFO:root:Added feature column 'desc_SpDiam_Dzv/1000' from descriptor 'SpDiam_Dzv'.
# INFO:root:Added feature column 'desc_SpAD_Dzv/1000' from descriptor 'SpAD_Dzv'.
# INFO:root:Added feature column 'desc_SpMAD_Dzv/10' from descriptor 'SpMAD_Dzv'.
# INFO:root:Added feature column 'desc_LogEE_Dzv/100' from descriptor 'LogEE_Dzv'.
# INFO:root:Added feature column 'desc_VE1_Dzv' from descriptor 'VE1_Dzv'.
# INFO:root:Added feature column 'desc_VE2_Dzv' from descriptor 'VE2_Dzv'.
# INFO:root:Added feature column 'desc_VE3_Dzv' from descriptor 'VE3_Dzv'.
# INFO:root:Added feature column 'desc_VR1_Dzv/100' from descriptor 'VR1_Dzv'.
# INFO:root:Added feature column 'desc_VR2_Dzv' from descriptor 'VR2_Dzv'.
# INFO:root:Added feature column 'desc_VR3_Dzv' from descriptor 'VR3_Dzv'.
# INFO:root:Added feature column 'desc_SpAbs_Dzse/1000' from descriptor 'SpAbs_Dzse'.
# INFO:root:Added feature column 'desc_SpMax_Dzse/100' from descriptor 'SpMax_Dzse'.
# INFO:root:Added feature column 'desc_SpDiam_Dzse/100' from descriptor 'SpDiam_Dzse'.
# INFO:root:Added feature column 'desc_SpAD_Dzse/1000' from descriptor 'SpAD_Dzse'.
# INFO:root:Added feature column 'desc_SpMAD_Dzse/10' from descriptor 'SpMAD_Dzse'.
# INFO:root:Added feature column 'desc_LogEE_Dzse/100' from descriptor 'LogEE_Dzse'.
# INFO:root:Added feature column 'desc_VE1_Dzse' from descriptor 'VE1_Dzse'.
# INFO:root:Added feature column 'desc_VE2_Dzse' from descriptor 'VE2_Dzse'.
# INFO:root:Added feature column 'desc_VE3_Dzse' from descriptor 'VE3_Dzse'.
# INFO:root:Added feature column 'desc_VR1_Dzse/100' from descriptor 'VR1_Dzse'.
# INFO:root:Added feature column 'desc_VR2_Dzse' from descriptor 'VR2_Dzse'.
# INFO:root:Added feature column 'desc_VR3_Dzse' from descriptor 'VR3_Dzse'.
# INFO:root:Added feature column 'desc_SpAbs_Dzpe/1000' from descriptor 'SpAbs_Dzpe'.
# INFO:root:Added feature column 'desc_SpMax_Dzpe/100' from descriptor 'SpMax_Dzpe'.
# INFO:root:Added feature column 'desc_SpDiam_Dzpe/100' from descriptor 'SpDiam_Dzpe'.
# INFO:root:Added feature column 'desc_SpAD_Dzpe/1000' from descriptor 'SpAD_Dzpe'.
# INFO:root:Added feature column 'desc_SpMAD_Dzpe/10' from descriptor 'SpMAD_Dzpe'.
# INFO:root:Added feature column 'desc_LogEE_Dzpe/100' from descriptor 'LogEE_Dzpe'.
# INFO:root:Added feature column 'desc_VE1_Dzpe' from descriptor 'VE1_Dzpe'.
# INFO:root:Added feature column 'desc_VE2_Dzpe' from descriptor 'VE2_Dzpe'.
# INFO:root:Added feature column 'desc_VE3_Dzpe' from descriptor 'VE3_Dzpe'.
# INFO:root:Added feature column 'desc_VR1_Dzpe/100' from descriptor 'VR1_Dzpe'.
# INFO:root:Added feature column 'desc_VR2_Dzpe' from descriptor 'VR2_Dzpe'.
# INFO:root:Added feature column 'desc_VR3_Dzpe' from descriptor 'VR3_Dzpe'.
# INFO:root:Added feature column 'desc_SpAbs_Dzare/1000' from descriptor 'SpAbs_Dzare'.
# INFO:root:Added feature column 'desc_SpMax_Dzare/100' from descriptor 'SpMax_Dzare'.
# INFO:root:Added feature column 'desc_SpDiam_Dzare/100' from descriptor 'SpDiam_Dzare'.
# INFO:root:Added feature column 'desc_SpAD_Dzare/1000' from descriptor 'SpAD_Dzare'.
# INFO:root:Added feature column 'desc_SpMAD_Dzare/10' from descriptor 'SpMAD_Dzare'.
# INFO:root:Added feature column 'desc_LogEE_Dzare/100' from descriptor 'LogEE_Dzare'.
# INFO:root:Added feature column 'desc_VE1_Dzare' from descriptor 'VE1_Dzare'.
# INFO:root:Added feature column 'desc_VE2_Dzare' from descriptor 'VE2_Dzare'.
# INFO:root:Added feature column 'desc_VE3_Dzare' from descriptor 'VE3_Dzare'.
# INFO:root:Added feature column 'desc_VR1_Dzare/100' from descriptor 'VR1_Dzare'.
# INFO:root:Added feature column 'desc_VR2_Dzare' from descriptor 'VR2_Dzare'.
# INFO:root:Added feature column 'desc_VR3_Dzare' from descriptor 'VR3_Dzare'.
# INFO:root:Added feature column 'desc_SpAbs_Dzp/1000' from descriptor 'SpAbs_Dzp'.
# INFO:root:Added feature column 'desc_SpMax_Dzp/100' from descriptor 'SpMax_Dzp'.
# INFO:root:Added feature column 'desc_SpDiam_Dzp/1000' from descriptor 'SpDiam_Dzp'.
# INFO:root:Added feature column 'desc_SpAD_Dzp/1000' from descriptor 'SpAD_Dzp'.
# INFO:root:Added feature column 'desc_SpMAD_Dzp/10' from descriptor 'SpMAD_Dzp'.
# INFO:root:Added feature column 'desc_LogEE_Dzp/100' from descriptor 'LogEE_Dzp'.
# INFO:root:Added feature column 'desc_VE1_Dzp' from descriptor 'VE1_Dzp'.
# INFO:root:Added feature column 'desc_VE2_Dzp' from descriptor 'VE2_Dzp'.
# INFO:root:Added feature column 'desc_VE3_Dzp' from descriptor 'VE3_Dzp'.
# INFO:root:Added feature column 'desc_VR1_Dzp/100' from descriptor 'VR1_Dzp'.
# INFO:root:Added feature column 'desc_VR2_Dzp' from descriptor 'VR2_Dzp'.
# INFO:root:Added feature column 'desc_VR3_Dzp' from descriptor 'VR3_Dzp'.
# INFO:root:Added feature column 'desc_SpAbs_Dzi/1000' from descriptor 'SpAbs_Dzi'.
# INFO:root:Added feature column 'desc_SpMax_Dzi/100' from descriptor 'SpMax_Dzi'.
# INFO:root:Added feature column 'desc_SpDiam_Dzi/100' from descriptor 'SpDiam_Dzi'.
# INFO:root:Added feature column 'desc_SpAD_Dzi/1000' from descriptor 'SpAD_Dzi'.
# INFO:root:Added feature column 'desc_SpMAD_Dzi/10' from descriptor 'SpMAD_Dzi'.
# INFO:root:Added feature column 'desc_LogEE_Dzi/100' from descriptor 'LogEE_Dzi'.
# INFO:root:Added feature column 'desc_SM1_Dzi' from descriptor 'SM1_Dzi'.
# INFO:root:Added feature column 'desc_VE1_Dzi' from descriptor 'VE1_Dzi'.
# INFO:root:Added feature column 'desc_VE2_Dzi' from descriptor 'VE2_Dzi'.
# INFO:root:Added feature column 'desc_VE3_Dzi' from descriptor 'VE3_Dzi'.
# INFO:root:Added feature column 'desc_VR1_Dzi/100' from descriptor 'VR1_Dzi'.
# INFO:root:Added feature column 'desc_VR2_Dzi' from descriptor 'VR2_Dzi'.
# INFO:root:Added feature column 'desc_VR3_Dzi' from descriptor 'VR3_Dzi'.
# INFO:root:Added feature column 'desc_BertzCT/100' from descriptor 'BertzCT'.
# INFO:root:Added feature column 'desc_nBonds/30' from descriptor 'nBonds'.
# INFO:root:Added feature column 'desc_nBondsO/10' from descriptor 'nBondsO'.
# INFO:root:Added feature column 'desc_nBondsS/30' from descriptor 'nBondsS'.
# INFO:root:Added feature column 'desc_nBondsD' from descriptor 'nBondsD'.
# INFO:root:Added feature column 'desc_nBondsT' from descriptor 'nBondsT'.
# INFO:root:Added feature column 'desc_nBondsA' from descriptor 'nBondsA'.
# INFO:root:Added feature column 'desc_nBondsM' from descriptor 'nBondsM'.
# INFO:root:Added feature column 'desc_nBondsKS/30' from descriptor 'nBondsKS'.
# INFO:root:Added feature column 'desc_nBondsKD' from descriptor 'nBondsKD'.
# INFO:root:Added feature column 'desc_RNCG' from descriptor 'RNCG'.
# INFO:root:Added feature column 'desc_RPCG' from descriptor 'RPCG'.
# INFO:root:Added feature column 'desc_C1SP1' from descriptor 'C1SP1'.
# INFO:root:Added feature column 'desc_C2SP1' from descriptor 'C2SP1'.
# INFO:root:Added feature column 'desc_C1SP2' from descriptor 'C1SP2'.
# INFO:root:Added feature column 'desc_C2SP2' from descriptor 'C2SP2'.
# INFO:root:Added feature column 'desc_C1SP3/10' from descriptor 'C1SP3'.
# INFO:root:Added feature column 'desc_C2SP3/10' from descriptor 'C2SP3'.
# INFO:root:Added feature column 'desc_C3SP3' from descriptor 'C3SP3'.
# INFO:root:Added feature column 'desc_HybRatio' from descriptor 'HybRatio'.
# INFO:root:Added feature column 'desc_FCSP3' from descriptor 'FCSP3'.
# INFO:root:Added feature column 'desc_Xch-5d' from descriptor 'Xch-5d'.
# INFO:root:Added feature column 'desc_Xch-6d' from descriptor 'Xch-6d'.
# INFO:root:Added feature column 'desc_Xch-7d' from descriptor 'Xch-7d'.
# INFO:root:Added feature column 'desc_Xch-6dv' from descriptor 'Xch-6dv'.
# INFO:root:Added feature column 'desc_Xch-7dv' from descriptor 'Xch-7dv'.
# INFO:root:Added feature column 'desc_Xc-5d' from descriptor 'Xc-5d'.
# INFO:root:Added feature column 'desc_Xpc-6d' from descriptor 'Xpc-6d'.
# INFO:root:Added feature column 'desc_Xpc-6dv' from descriptor 'Xpc-6dv'.
# INFO:root:Added feature column 'desc_Xp-0d/10' from descriptor 'Xp-0d'.
# INFO:root:Added feature column 'desc_Xp-1d/10' from descriptor 'Xp-1d'.
# INFO:root:Added feature column 'desc_Xp-2d/10' from descriptor 'Xp-2d'.
# INFO:root:Added feature column 'desc_Xp-3d/10' from descriptor 'Xp-3d'.
# INFO:root:Added feature column 'desc_Xp-4d' from descriptor 'Xp-4d'.
# INFO:root:Added feature column 'desc_Xp-5d' from descriptor 'Xp-5d'.
# INFO:root:Added feature column 'desc_Xp-6d' from descriptor 'Xp-6d'.
# INFO:root:Added feature column 'desc_Xp-7d' from descriptor 'Xp-7d'.
# INFO:root:Added feature column 'desc_AXp-0d' from descriptor 'AXp-0d'.
# INFO:root:Added feature column 'desc_AXp-1d' from descriptor 'AXp-1d'.
# INFO:root:Added feature column 'desc_AXp-3d' from descriptor 'AXp-3d'.
# INFO:root:Added feature column 'desc_AXp-4d' from descriptor 'AXp-4d'.
# INFO:root:Added feature column 'desc_AXp-5d' from descriptor 'AXp-5d'.
# INFO:root:Added feature column 'desc_AXp-6d' from descriptor 'AXp-6d'.
# INFO:root:Added feature column 'desc_AXp-7d' from descriptor 'AXp-7d'.
# INFO:root:Added feature column 'desc_Xp-0dv/10' from descriptor 'Xp-0dv'.
# INFO:root:Added feature column 'desc_Xp-1dv/10' from descriptor 'Xp-1dv'.
# INFO:root:Added feature column 'desc_Xp-2dv/10' from descriptor 'Xp-2dv'.
# INFO:root:Added feature column 'desc_Xp-3dv/10' from descriptor 'Xp-3dv'.
# INFO:root:Added feature column 'desc_Xp-4dv' from descriptor 'Xp-4dv'.
# INFO:root:Added feature column 'desc_Xp-5dv' from descriptor 'Xp-5dv'.
# INFO:root:Added feature column 'desc_Xp-6dv' from descriptor 'Xp-6dv'.
# INFO:root:Added feature column 'desc_Xp-7dv' from descriptor 'Xp-7dv'.
# INFO:root:Added feature column 'desc_AXp-0dv' from descriptor 'AXp-0dv'.
# INFO:root:Added feature column 'desc_AXp-1dv' from descriptor 'AXp-1dv'.
# INFO:root:Added feature column 'desc_AXp-2dv' from descriptor 'AXp-2dv'.
# INFO:root:Added feature column 'desc_AXp-3dv' from descriptor 'AXp-3dv'.
# INFO:root:Added feature column 'desc_AXp-4dv' from descriptor 'AXp-4dv'.
# INFO:root:Added feature column 'desc_AXp-5dv' from descriptor 'AXp-5dv'.
# INFO:root:Added feature column 'desc_AXp-6dv' from descriptor 'AXp-6dv'.
# INFO:root:Added feature column 'desc_AXp-7dv' from descriptor 'AXp-7dv'.
# INFO:root:Added feature column 'desc_SZ/30' from descriptor 'SZ'.
# INFO:root:Added feature column 'desc_Sm/10' from descriptor 'Sm'.
# INFO:root:Added feature column 'desc_Sv/30' from descriptor 'Sv'.
# INFO:root:Added feature column 'desc_Sse/30' from descriptor 'Sse'.
# INFO:root:Added feature column 'desc_Spe/30' from descriptor 'Spe'.
# INFO:root:Added feature column 'desc_Sare/30' from descriptor 'Sare'.
# INFO:root:Added feature column 'desc_Sp/30' from descriptor 'Sp'.
# INFO:root:Added feature column 'desc_Si/30' from descriptor 'Si'.
# INFO:root:Added feature column 'desc_MZ' from descriptor 'MZ'.
# INFO:root:Added feature column 'desc_Mm' from descriptor 'Mm'.
# INFO:root:Added feature column 'desc_Mv' from descriptor 'Mv'.
# INFO:root:Added feature column 'desc_Mp' from descriptor 'Mp'.
# INFO:root:Added feature column 'desc_Mi' from descriptor 'Mi'.
# INFO:root:Added feature column 'desc_SpAbs_D/1000' from descriptor 'SpAbs_D'.
# INFO:root:Added feature column 'desc_SpMax_D/100' from descriptor 'SpMax_D'.
# INFO:root:Added feature column 'desc_SpDiam_D/1000' from descriptor 'SpDiam_D'.
# INFO:root:Added feature column 'desc_SpAD_D/1000' from descriptor 'SpAD_D'.
# INFO:root:Added feature column 'desc_SpMAD_D/10' from descriptor 'SpMAD_D'.
# INFO:root:Added feature column 'desc_LogEE_D/100' from descriptor 'LogEE_D'.
# INFO:root:Added feature column 'desc_VE1_D' from descriptor 'VE1_D'.
# INFO:root:Added feature column 'desc_VE2_D' from descriptor 'VE2_D'.
# INFO:root:Added feature column 'desc_VE3_D' from descriptor 'VE3_D'.
# INFO:root:Added feature column 'desc_VR1_D/100' from descriptor 'VR1_D'.
# INFO:root:Added feature column 'desc_VR2_D' from descriptor 'VR2_D'.
# INFO:root:Added feature column 'desc_VR3_D' from descriptor 'VR3_D'.
# INFO:root:Added feature column 'desc_NsCH3' from descriptor 'NsCH3'.
# INFO:root:Added feature column 'desc_NssCH2/10' from descriptor 'NssCH2'.
# INFO:root:Added feature column 'desc_NtCH' from descriptor 'NtCH'.
# INFO:root:Added feature column 'desc_NdsCH' from descriptor 'NdsCH'.
# INFO:root:Added feature column 'desc_NaaCH' from descriptor 'NaaCH'.
# INFO:root:Added feature column 'desc_NsssCH' from descriptor 'NsssCH'.
# INFO:root:Added feature column 'desc_NtsC' from descriptor 'NtsC'.
# INFO:root:Added feature column 'desc_NaasC' from descriptor 'NaasC'.
# INFO:root:Added feature column 'desc_NsNH2' from descriptor 'NsNH2'.
# INFO:root:Added feature column 'desc_NssNH' from descriptor 'NssNH'.
# INFO:root:Added feature column 'desc_NaaNH' from descriptor 'NaaNH'.
# INFO:root:Added feature column 'desc_NaaN' from descriptor 'NaaN'.
# INFO:root:Added feature column 'desc_NsssN' from descriptor 'NsssN'.
# INFO:root:Added feature column 'desc_NaasN' from descriptor 'NaasN'.
# INFO:root:Added feature column 'desc_SsCH3' from descriptor 'SsCH3'.
# INFO:root:Added feature column 'desc_SssCH2/10' from descriptor 'SssCH2'.
# INFO:root:Added feature column 'desc_StCH' from descriptor 'StCH'.
# INFO:root:Added feature column 'desc_SdsCH' from descriptor 'SdsCH'.
# INFO:root:Added feature column 'desc_SaaCH' from descriptor 'SaaCH'.
# INFO:root:Added feature column 'desc_SsssCH' from descriptor 'SsssCH'.
# INFO:root:Added feature column 'desc_StsC' from descriptor 'StsC'.
# INFO:root:Added feature column 'desc_log_SdssC' from descriptor 'log_SdssC'.
# INFO:root:Added feature column 'desc_SaasC' from descriptor 'SaasC'.
# INFO:root:Added feature column 'desc_SsNH2/10' from descriptor 'SsNH2'.
# INFO:root:Added feature column 'desc_SssNH' from descriptor 'SssNH'.
# INFO:root:Added feature column 'desc_SaaNH' from descriptor 'SaaNH'.
# INFO:root:Added feature column 'desc_SaaN' from descriptor 'SaaN'.
# INFO:root:Added feature column 'desc_SsssN' from descriptor 'SsssN'.
# INFO:root:Added feature column 'desc_SaasN' from descriptor 'SaasN'.
# INFO:root:Added feature column 'desc_SdO/10' from descriptor 'SdO'.
# INFO:root:Added feature column 'desc_MAXsssCH' from descriptor 'MAXsssCH'.
# INFO:root:Added feature column 'desc_MAXdssC' from descriptor 'MAXdssC'.
# INFO:root:Added feature column 'desc_MAXssNH' from descriptor 'MAXssNH'.
# INFO:root:Added feature column 'desc_MAXdO/10' from descriptor 'MAXdO'.
# INFO:root:Added feature column 'desc_MINssCH2' from descriptor 'MINssCH2'.
# INFO:root:Added feature column 'desc_MINsssCH' from descriptor 'MINsssCH'.
# INFO:root:Added feature column 'desc_MINdssC' from descriptor 'MINdssC'.
# INFO:root:Added feature column 'desc_MINssNH' from descriptor 'MINssNH'.
# INFO:root:Added feature column 'desc_MINdO/10' from descriptor 'MINdO'.
# INFO:root:Added feature column 'desc_ECIndex/1000' from descriptor 'ECIndex'.
# INFO:root:Added feature column 'desc_ETA_alpha/10' from descriptor 'ETA_alpha'.
# INFO:root:Added feature column 'desc_ETA_shape_p' from descriptor 'ETA_shape_p'.
# INFO:root:Added feature column 'desc_ETA_beta/10' from descriptor 'ETA_beta'.
# INFO:root:Added feature column 'desc_AETA_beta' from descriptor 'AETA_beta'.
# INFO:root:Added feature column 'desc_ETA_beta_s/10' from descriptor 'ETA_beta_s'.
# INFO:root:Added feature column 'desc_ETA_beta_ns' from descriptor 'ETA_beta_ns'.
# INFO:root:Added feature column 'desc_AETA_beta_ns' from descriptor 'AETA_beta_ns'.
# INFO:root:Added feature column 'desc_ETA_beta_ns_d' from descriptor 'ETA_beta_ns_d'.
# INFO:root:Added feature column 'desc_AETA_beta_ns_d' from descriptor 'AETA_beta_ns_d'.
# INFO:root:Added feature column 'desc_ETA_eta/30' from descriptor 'ETA_eta'.
# INFO:root:Added feature column 'desc_ETA_eta_L/10' from descriptor 'ETA_eta_L'.
# INFO:root:Added feature column 'desc_AETA_eta_L' from descriptor 'AETA_eta_L'.
# INFO:root:Added feature column 'desc_ETA_eta_R/30' from descriptor 'ETA_eta_R'.
# INFO:root:Added feature column 'desc_AETA_eta_R' from descriptor 'AETA_eta_R'.
# INFO:root:Added feature column 'desc_ETA_eta_RL/10' from descriptor 'ETA_eta_RL'.
# INFO:root:Added feature column 'desc_AETA_eta_RL' from descriptor 'AETA_eta_RL'.
# INFO:root:Added feature column 'desc_ETA_eta_F/10' from descriptor 'ETA_eta_F'.
# INFO:root:Added feature column 'desc_AETA_eta_F' from descriptor 'AETA_eta_F'.
# INFO:root:Added feature column 'desc_ETA_eta_FL' from descriptor 'ETA_eta_FL'.
# INFO:root:Added feature column 'desc_AETA_eta_FL' from descriptor 'AETA_eta_FL'.
# INFO:root:Added feature column 'desc_AETA_eta_BR' from descriptor 'AETA_eta_BR'.
# INFO:root:Added feature column 'desc_ETA_epsilon_3' from descriptor 'ETA_epsilon_3'.
# INFO:root:Added feature column 'desc_ETA_epsilon_5' from descriptor 'ETA_epsilon_5'.
# INFO:root:Added feature column 'desc_ETA_dEpsilon_B' from descriptor 'ETA_dEpsilon_B'.
# INFO:root:Added feature column 'desc_ETA_dEpsilon_C' from descriptor 'ETA_dEpsilon_C'.
# INFO:root:Added feature column 'desc_ETA_dEpsilon_D' from descriptor 'ETA_dEpsilon_D'.
# INFO:root:Added feature column 'desc_ETA_dBeta/10' from descriptor 'ETA_dBeta'.
# INFO:root:Added feature column 'desc_AETA_dBeta' from descriptor 'AETA_dBeta'.
# INFO:root:Added feature column 'desc_fragCpx/10' from descriptor 'fragCpx'.
# INFO:root:Added feature column 'desc_fMF' from descriptor 'fMF'.
# INFO:root:Added feature column 'desc_nHBAcc' from descriptor 'nHBAcc'.
# INFO:root:Added feature column 'desc_nHBDon' from descriptor 'nHBDon'.
# INFO:root:Added feature column 'desc_IC1' from descriptor 'IC1'.
# INFO:root:Added feature column 'desc_IC5' from descriptor 'IC5'.
# INFO:root:Added feature column 'desc_TIC0/30' from descriptor 'TIC0'.
# INFO:root:Added feature column 'desc_TIC1/100' from descriptor 'TIC1'.
# INFO:root:Added feature column 'desc_TIC2/100' from descriptor 'TIC2'.
# INFO:root:Added feature column 'desc_TIC3/100' from descriptor 'TIC3'.
# INFO:root:Added feature column 'desc_TIC4/100' from descriptor 'TIC4'.
# INFO:root:Added feature column 'desc_TIC5/100' from descriptor 'TIC5'.
# INFO:root:Added feature column 'desc_SIC1' from descriptor 'SIC1'.
# INFO:root:Added feature column 'desc_BIC1' from descriptor 'BIC1'.
# INFO:root:Added feature column 'desc_CIC0' from descriptor 'CIC0'.
# INFO:root:Added feature column 'desc_MIC1/10' from descriptor 'MIC1'.
# INFO:root:Added feature column 'desc_ZMIC0/100' from descriptor 'ZMIC0'.
# INFO:root:Added feature column 'desc_ZMIC1/30' from descriptor 'ZMIC1'.
# INFO:root:Added feature column 'desc_Kier1/10' from descriptor 'Kier1'.
# INFO:root:Added feature column 'desc_Kier2/10' from descriptor 'Kier2'.
# INFO:root:Added feature column 'desc_Kier3/10' from descriptor 'Kier3'.
# INFO:root:Added feature column 'desc_VMcGowan/100' from descriptor 'VMcGowan'.
# INFO:root:Added feature column 'desc_LabuteASA/100' from descriptor 'LabuteASA'.
# INFO:root:Added feature column 'desc_PEOE_VSA1/10' from descriptor 'PEOE_VSA1'.
# INFO:root:Added feature column 'desc_PEOE_VSA2/10' from descriptor 'PEOE_VSA2'.
# INFO:root:Added feature column 'desc_PEOE_VSA3/10' from descriptor 'PEOE_VSA3'.
# INFO:root:Added feature column 'desc_PEOE_VSA4' from descriptor 'PEOE_VSA4'.
# INFO:root:Added feature column 'desc_PEOE_VSA5/10' from descriptor 'PEOE_VSA5'.
# INFO:root:Added feature column 'desc_PEOE_VSA8/10' from descriptor 'PEOE_VSA8'.
# INFO:root:Added feature column 'desc_PEOE_VSA10/10' from descriptor 'PEOE_VSA10'.
# INFO:root:Added feature column 'desc_SMR_VSA3/10' from descriptor 'SMR_VSA3'.
# INFO:root:Added feature column 'desc_SMR_VSA4/10' from descriptor 'SMR_VSA4'.
# INFO:root:Added feature column 'desc_SMR_VSA6/10' from descriptor 'SMR_VSA6'.
# INFO:root:Added feature column 'desc_SMR_VSA7/10' from descriptor 'SMR_VSA7'.
# INFO:root:Added feature column 'desc_SMR_VSA9/10' from descriptor 'SMR_VSA9'.
# INFO:root:Added feature column 'desc_SlogP_VSA1/10' from descriptor 'SlogP_VSA1'.
# INFO:root:Added feature column 'desc_SlogP_VSA2/30' from descriptor 'SlogP_VSA2'.
# INFO:root:Added feature column 'desc_SlogP_VSA3/10' from descriptor 'SlogP_VSA3'.
# INFO:root:Added feature column 'desc_SlogP_VSA6/10' from descriptor 'SlogP_VSA6'.
# INFO:root:Added feature column 'desc_SlogP_VSA10' from descriptor 'SlogP_VSA10'.
# INFO:root:Added feature column 'desc_EState_VSA4/30' from descriptor 'EState_VSA4'.
# INFO:root:Added feature column 'desc_EState_VSA6/10' from descriptor 'EState_VSA6'.
# INFO:root:Added feature column 'desc_EState_VSA7/10' from descriptor 'EState_VSA7'.
# INFO:root:Added feature column 'desc_EState_VSA9' from descriptor 'EState_VSA9'.
# INFO:root:Added feature column 'desc_VSA_EState2/10' from descriptor 'VSA_EState2'.
# INFO:root:Added feature column 'desc_VSA_EState3' from descriptor 'VSA_EState3'.
# INFO:root:Added feature column 'desc_VSA_EState6' from descriptor 'VSA_EState6'.
# INFO:root:Added feature column 'desc_VSA_EState7/10' from descriptor 'VSA_EState7'.
# INFO:root:Added feature column 'desc_VSA_EState8/10' from descriptor 'VSA_EState8'.
# INFO:root:Added feature column 'desc_MDEC-11' from descriptor 'MDEC-11'.
# INFO:root:Added feature column 'desc_MDEC-23/10' from descriptor 'MDEC-23'.
# INFO:root:Added feature column 'desc_MDEC-33' from descriptor 'MDEC-33'.
# INFO:root:Added feature column 'desc_MID/30' from descriptor 'MID'.
# INFO:root:Added feature column 'desc_AMID' from descriptor 'AMID'.
# INFO:root:Added feature column 'desc_MID_C/30' from descriptor 'MID_C'.
# INFO:root:Added feature column 'desc_AMID_C' from descriptor 'AMID_C'.
# INFO:root:Added feature column 'desc_MID_N' from descriptor 'MID_N'.
# INFO:root:Added feature column 'desc_AMID_O' from descriptor 'AMID_O'.
# INFO:root:Added feature column 'desc_MPC2/10' from descriptor 'MPC2'.
# INFO:root:Added feature column 'desc_MPC3/10' from descriptor 'MPC3'.
# INFO:root:Added feature column 'desc_MPC4/10' from descriptor 'MPC4'.
# INFO:root:Added feature column 'desc_MPC5/30' from descriptor 'MPC5'.
# INFO:root:Added feature column 'desc_MPC6/10' from descriptor 'MPC6'.
# INFO:root:Added feature column 'desc_MPC7/30' from descriptor 'MPC7'.
# INFO:root:Added feature column 'desc_MPC8/30' from descriptor 'MPC8'.
# INFO:root:Added feature column 'desc_MPC9/30' from descriptor 'MPC9'.
# INFO:root:Added feature column 'desc_MPC10/30' from descriptor 'MPC10'.
# INFO:root:Added feature column 'desc_TMPC10/100' from descriptor 'TMPC10'.
# INFO:root:Added feature column 'desc_piPC1' from descriptor 'piPC1'.
# INFO:root:Added feature column 'desc_piPC2' from descriptor 'piPC2'.
# INFO:root:Added feature column 'desc_piPC3' from descriptor 'piPC3'.
# INFO:root:Added feature column 'desc_piPC4' from descriptor 'piPC4'.
# INFO:root:Added feature column 'desc_piPC5' from descriptor 'piPC5'.
# INFO:root:Added feature column 'desc_piPC6' from descriptor 'piPC6'.
# INFO:root:Added feature column 'desc_piPC7' from descriptor 'piPC7'.
# INFO:root:Added feature column 'desc_piPC8' from descriptor 'piPC8'.
# INFO:root:Added feature column 'desc_piPC9' from descriptor 'piPC9'.
# INFO:root:Added feature column 'desc_piPC10' from descriptor 'piPC10'.
# INFO:root:Added feature column 'desc_TpiPC10' from descriptor 'TpiPC10'.
# INFO:root:Added feature column 'desc_apol/30' from descriptor 'apol'.
# INFO:root:Added feature column 'desc_bpol/30' from descriptor 'bpol'.
# INFO:root:Added feature column 'desc_nRing' from descriptor 'nRing'.
# INFO:root:Added feature column 'desc_n5Ring' from descriptor 'n5Ring'.
# INFO:root:Added feature column 'desc_n6Ring' from descriptor 'n6Ring'.
# INFO:root:Added feature column 'desc_nHRing' from descriptor 'nHRing'.
# INFO:root:Added feature column 'desc_n5HRing' from descriptor 'n5HRing'.
# INFO:root:Added feature column 'desc_n6HRing' from descriptor 'n6HRing'.
# INFO:root:Added feature column 'desc_naRing' from descriptor 'naRing'.
# INFO:root:Added feature column 'desc_n5aRing' from descriptor 'n5aRing'.
# INFO:root:Added feature column 'desc_naHRing' from descriptor 'naHRing'.
# INFO:root:Added feature column 'desc_n5aHRing' from descriptor 'n5aHRing'.
# INFO:root:Added feature column 'desc_nARing' from descriptor 'nARing'.
# INFO:root:Added feature column 'desc_n6ARing' from descriptor 'n6ARing'.
# INFO:root:Added feature column 'desc_nAHRing' from descriptor 'nAHRing'.
# INFO:root:Added feature column 'desc_n6AHRing' from descriptor 'n6AHRing'.
# INFO:root:Added feature column 'desc_nRot/10' from descriptor 'nRot'.
# INFO:root:Added feature column 'desc_RotRatio' from descriptor 'RotRatio'.
# INFO:root:Added feature column 'desc_SLogP/10' from descriptor 'SLogP'.
# INFO:root:Added feature column 'desc_SMR/100' from descriptor 'SMR'.
# INFO:root:Added feature column 'desc_TopoPSA(NO)/30' from descriptor 'TopoPSA(NO)'.
# INFO:root:Added feature column 'desc_TopoPSA/30' from descriptor 'TopoPSA'.
# INFO:root:Added feature column 'desc_GGI8' from descriptor 'GGI8'.
# INFO:root:Added feature column 'desc_GGI10' from descriptor 'GGI10'.
# INFO:root:Added feature column 'desc_JGI1' from descriptor 'JGI1'.
# INFO:root:Added feature column 'desc_JGI2' from descriptor 'JGI2'.
# INFO:root:Added feature column 'desc_JGI3' from descriptor 'JGI3'.
# INFO:root:Added feature column 'desc_JGI8' from descriptor 'JGI8'.
# INFO:root:Added feature column 'desc_JGI10' from descriptor 'JGI10'.
# INFO:root:Added feature column 'desc_JGT10' from descriptor 'JGT10'.
# INFO:root:Added feature column 'desc_Diameter/10' from descriptor 'Diameter'.
# INFO:root:Added feature column 'desc_Radius/10' from descriptor 'Radius'.
# INFO:root:Added feature column 'desc_TopoShapeIndex' from descriptor 'TopoShapeIndex'.
# INFO:root:Added feature column 'desc_PetitjeanIndex' from descriptor 'PetitjeanIndex'.
# INFO:root:Added feature column 'desc_Vabc/100' from descriptor 'Vabc'.
# INFO:root:Added feature column 'desc_VAdjMat' from descriptor 'VAdjMat'.
# INFO:root:Added feature column 'desc_MWC01/10' from descriptor 'MWC01'.
# INFO:root:Added feature column 'desc_MWC02' from descriptor 'MWC02'.
# INFO:root:Added feature column 'desc_MWC03' from descriptor 'MWC03'.
# INFO:root:Added feature column 'desc_MWC04' from descriptor 'MWC04'.
# INFO:root:Added feature column 'desc_MWC05' from descriptor 'MWC05'.
# INFO:root:Added feature column 'desc_MWC06' from descriptor 'MWC06'.
# INFO:root:Added feature column 'desc_MWC07' from descriptor 'MWC07'.
# INFO:root:Added feature column 'desc_MWC08' from descriptor 'MWC08'.
# INFO:root:Added feature column 'desc_MWC09/10' from descriptor 'MWC09'.
# INFO:root:Added feature column 'desc_MWC10/10' from descriptor 'MWC10'.
# INFO:root:Added feature column 'desc_TMWC10/30' from descriptor 'TMWC10'.
# INFO:root:Added feature column 'desc_SRW02' from descriptor 'SRW02'.
# INFO:root:Added feature column 'desc_SRW04' from descriptor 'SRW04'.
# INFO:root:Added feature column 'desc_SRW05' from descriptor 'SRW05'.
# INFO:root:Added feature column 'desc_SRW06' from descriptor 'SRW06'.
# INFO:root:Added feature column 'desc_SRW07' from descriptor 'SRW07'.
# INFO:root:Added feature column 'desc_SRW08' from descriptor 'SRW08'.
# INFO:root:Added feature column 'desc_SRW09' from descriptor 'SRW09'.
# INFO:root:Added feature column 'desc_SRW10' from descriptor 'SRW10'.
# INFO:root:Added feature column 'desc_MW/100' from descriptor 'MW'.
# INFO:root:Added feature column 'desc_AMW' from descriptor 'AMW'.
# INFO:root:Added feature column 'desc_WPath/10000' from descriptor 'WPath'.
# INFO:root:Added feature column 'desc_WPol/10' from descriptor 'WPol'.
# INFO:root:Added feature column 'desc_Zagreb1/100' from descriptor 'Zagreb1'.
# INFO:root:Added feature column 'desc_Zagreb2/100' from descriptor 'Zagreb2'.
# INFO:root:Added feature column 'desc_mZagreb2/10' from descriptor 'mZagreb2'.
# INFO:root:Augmented heldout data (with 813 descriptors) saved to ../data/LNPDB_for_AGILE/outputs\finetuning_set_smiles_plus_features_plus_features.csv

# %% [markdown]
# ## 4.2 Validate descriptor generation

# %%
# Compare generated Mordred descriptors vs. known features, with summary stats
def compare_descriptors(generated_path: str, known_path: str, n_check: int = 5,
                        atol: float = 1e-6, rtol: float = 1e-4):
    """
    Compare a generated Mordred descriptor CSV to a known training feature CSV.

    Parameters:
    - generated_path: path to heldout_data_output.csv (with descriptors)
    - known_path: path to finetuning_set_smiles_plus_features.csv
    - n_check: number of molecules to sample for detailed row comparison
    - atol, rtol: tolerances for numerical equality (absolute, relative)
    """
    df_gen = pd.read_csv(generated_path)
    df_known = pd.read_csv(known_path)

    # Select only descriptor columns (start with desc_)
    gen_cols = [c for c in df_gen.columns if c.startswith("desc_")]
    known_cols = [c for c in df_known.columns if c.startswith("desc_")]

    # Check overlap
    overlap = sorted(set(gen_cols) & set(known_cols))
    missing_in_gen = set(known_cols) - set(gen_cols)
    extra_in_gen = set(gen_cols) - set(known_cols)

    print(f"Total known features: {len(known_cols)}")
    print(f"Total generated features: {len(gen_cols)}")
    print(f"Overlap: {len(overlap)}")
    if missing_in_gen:
        print(f"❌ Missing in generated: {sorted(list(missing_in_gen))[:10]} ...")
    if extra_in_gen:
        print(f"⚠️ Extra in generated: {sorted(list(extra_in_gen))[:10]} ...")

    # Early exit if no overlap
    if not overlap:
        print("No overlapping descriptors to compare.")
        return

    # Align dataframes to overlap
    df_gen_overlap = df_gen[overlap].reset_index(drop=True)
    df_known_overlap = df_known[overlap].reset_index(drop=True)

    # Check shape match
    n_rows = min(len(df_gen_overlap), len(df_known_overlap))
    df_gen_overlap = df_gen_overlap.iloc[:n_rows]
    df_known_overlap = df_known_overlap.iloc[:n_rows]

    # Compare all values
    diffs_mask = ~np.isclose(df_gen_overlap.values,
                             df_known_overlap.values,
                             atol=atol, rtol=rtol, equal_nan=True)

    n_total = diffs_mask.size
    n_diffs = np.count_nonzero(diffs_mask)
    pct_match = 100 * (1 - n_diffs / n_total)

    # Molecule-level agreement
    row_match = np.all(~diffs_mask, axis=1)
    pct_rows_match = 100 * np.mean(row_match)

    print(f"\nSummary:")
    print(f"- Total values compared: {n_total}")
    print(f"- Mismatched values: {n_diffs}")
    print(f"- % values matching: {pct_match:.2f}%")
    print(f"- % molecules with all descriptors matching: {pct_rows_match:.2f}%")

    # Column order check (binary)
    same_order = gen_cols == known_cols
    print(f"Column order identical: {same_order}")

# generate features using original AGILE data; can be done with previous code chunk
# heldout_data(
#     "../LNPDB/data/LNPDB_for_AGILE/AGILE/data/data/finetuning_set_smiles_plus_features.csv", # only change this argument for each dataset
#     "../LNPDB/data/LNPDB_for_AGILE/outputs",
#     "../LNPDB/data/LNPDB_for_AGILE/AGILE/data/data/finetuning_set_smiles_plus_features.csv"
# )
            
# verify mordred generation algorithm on original AGILE data
compare_descriptors(
    "../data/LNPDB_for_AGILE/outputs/finetuning_set_smiles_plus_features_plus_features.csv",
    "../data/LNPDB_for_AGILE/AGILE/data/data/finetuning_set_smiles_plus_features.csv"
)
# Out:
# Total known features: 813
# Total generated features: 813
# Overlap: 813
#
# Summary:
# - Total values compared: 975600
# - Mismatched values: 0
# - % values matching: 100.00%
# - % molecules with all descriptors matching: 100.00%
#
# Checking 5 random molecules for descriptor agreement:
# Row 510: ✅ all overlapping descriptors match
# Row 1170: ✅ all overlapping descriptors match
# Row 495: ✅ all overlapping descriptors match
# Row 562: ✅ all overlapping descriptors match
# Row 379: ✅ all overlapping descriptors match

# %% [markdown]
# # 5. Evaluating models on AGILE and LNPDB data

# %% [markdown]
# Once the molecular feature descriptors are generated, AGILE splits can make predictions on delivery efficacy for LNPDB data.
#
# The following blocks move`infer_vis_LNPDB.py` into AGILE from `LNPDB/data/LNPDB_for_AGILE/scripts`, evaluate the fine-tuned AGILE models on the test cross-evaluation splits and make predictions on data.

# %% [markdown]
# ## 5.1 Preparing infer_vis_LNPDB.py

# %%
# IMPORTANT: hardcode which csvs into infer_vis

# Copy infer_vis_LNPDB.py and infer yaml into AGILE model folders
infer_py = scripts_dir / "infer_vis_LNPDB.py"
infer_yaml_template = scripts_dir / "infer_vis/config_finetune.yaml"

# Ensure files exist
assert infer_py.exists(), "infer_vis_LNPDB.py not found in scripts/"
assert infer_yaml_template.exists(), "infer_vis/config_finetune.yaml not found in scripts/"

# Copy infer_vis_LNPDB.py into AGILE
shutil.copy(infer_py, agile_dir / "infer_vis_LNPDB.py")

# # Copy yaml into each split's checkpoints folder
# for i in range(5):
#     ckpt_dir = agile_dir / f"finetune/agile_lnp_hela_cv_{i}/checkpoints"
#     ckpt_dir.mkdir(parents=True, exist_ok=True)
#     shutil.copy(infer_yaml_template, ckpt_dir / "config_finetune.yaml")

logging.info("infer_vis_LNPDB.py copied.")

# %% [markdown]
# ## 5.2 Evaluate fine-tuned models on test splits

# %%
# do cross-validation on the test splits
def test_split_validation() -> None:
    """
    Run the AGILE cross-evaluation splits on respective test splits
    """
    cv_number_list = [0, 1, 2, 3, 4]
    # run infer_vis
    for cv_number in cv_number_list:
        model_path = agile_dir / f"finetune/agile_lnp_hela_cv_{cv_number}"
        yaml_path = agile_dir / f"finetune/agile_lnp_hela_cv_{cv_number}/checkpoints/config_finetune.yaml"
        # replace yaml value based on dataset_name
        with open(yaml_path, "r") as f:
            yaml_text = f.read()
        yaml_text = yaml_text.replace("task_name: lnp_hela_with_feat", f"task_name: df{cv_number}_test")
        with open(yaml_path, "w") as f:
            f.write(yaml_text)
        command = ["python", str(agile_dir / "infer_vis_LNPDB.py"), str(model_path)]
        result = subprocess.run(command, cwd=agile_dir, capture_output=True, text=True)
        print(result.stdout)
        print(result.stderr)

        # TODO: update directory??
        # preds_path = agile_dir / f"finetune/agile_lnp_hela_cv_{cv_number}/LNPDB/preds_on_LNPDB.csv"
        # if preds_path.exists():
        #     df_preds = pd.read_csv(preds_path)
        #     save_dir = Path(dataset_name)
        #     save_dir.mkdir(parents=True, exist_ok=True)
        #     save_preds_path = save_dir / f"{dataset_name}_preds_on_LNPDB_cv_{cv_number}.csv"
        #     df_preds.to_csv(save_preds_path, index=False)
        #     logging.info(f"Predictions for split {cv_number} saved to {save_preds_path}")

test_split_validation()

# %% [markdown]
# ## 5.3 Make predictions on LNPDB data

# %%
# evaluate cross-validation splits on dataset
def cross_evaluate() -> None:
    """
    Run the AGILE cross-evaluation splits on LNPDB data
    """
    cv_number_list = [0, 1, 2, 3, 4]
    # datasets to evaluate
    datasets = ["SL_2020_heldout_data"]
    for dataset_name of datasets:
        # run infer_vis
        for cv_number in cv_number_list:
            model_path = agile_dir / f"finetune/agile_lnp_hela_cv_{cv_number}"
            yaml_path = agile_dir / f"finetune/agile_lnp_hela_cv_{cv_number}/checkpoints/config_finetune.yaml"
            # replace yaml value based on dataset_name
            with open(yaml_path, "r") as f:
                yaml_text = f.read()
            yaml_text = yaml_text.replace("task_name: lnp_hela_with_feat", f"task_name: {dataset_name}")
            with open(yaml_path, "w") as f:
                f.write(yaml_text)
            command = ["python", str(agile_dir / "infer_vis_LNPDB.py"), str(model_path)]
            result = subprocess.run(command, cwd=agile_dir, capture_output=True, text=True)
            print(result.stdout)
            print(result.stderr)

            # TODO: update directory??
            # preds_path = agile_dir / f"finetune/agile_lnp_hela_cv_{cv_number}/LNPDB/preds_on_LNPDB.csv"
            # if preds_path.exists():
            #     df_preds = pd.read_csv(preds_path)
            #     save_dir = Path(dataset_name)
            #     save_dir.mkdir(parents=True, exist_ok=True)
            #     save_preds_path = save_dir / f"{dataset_name}_preds_on_LNPDB_cv_{cv_number}.csv"
            #     df_preds.to_csv(save_preds_path, index=False)
            #     logging.info(f"Predictions for split {cv_number} saved to {save_preds_path}")

cross_evaluate()
